# %% [markdown]
# # 균일 HSBM n 변화 - 가우시안 랜덤 프로젝션
#
# 이 노트북은 균일 HSBM의 `n` 변화 실험을 `가우시안 랜덤 프로젝션` 방식으로 실행한다.
#
# 가우시안 랜덤 프로젝션은 `Theta`에 Gaussian test matrix를 곱해 낮은 차원의 부분공간을 만든 뒤, 작은 core matrix의 고유벡터를 원래 공간으로 lift한다.
#
# 하이퍼그래프 생성식은 기존 비랜덤 실험과 동일하게 `p_in = a_in * rho_n / n ** (m - 1)`, `p_out = b_out * rho_n / n ** (m - 1)`를 사용한다.

# %% [markdown]
# ## 실행 설정
#
# 공통 실행 코드는 `uniform_hsbm_randomized.py`에 두었다. 이 노트북은 해당 실행기를 호출하고, raw CSV, summary CSV, 설정 JSON, 요약 그림을 `results/` 아래에 저장한다.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "src" / "common.py").exists():
        PROJECT_ROOT = candidate
        break

EXPERIMENT_DIR = PROJECT_ROOT / "experiments" / "균일 HSBM 실험"
if str(EXPERIMENT_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENT_DIR))

from uniform_hsbm_randomized import resolve_spec, run_named_experiment

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)
SPEC = resolve_spec(sweep='n', method='gaussian_random_projection')
SPEC
# Out:
# SweepSpec(sweep='n', method='gaussian_random_projection', experiment_id='EXP-20260428-003', experiment_slug='uniform_hsbm_n_scaling_gaussian_random_projection', notebook_name='n변화_gaussian_random_projection.ipynb', title_ko='균일 HSBM n 변화 - 가우시안 랜덤 프로젝션', x_col='n', x_values=(1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000), n=None, K=3, m=3, a_in=36.0, b_out=4.0, rho_n=4.0, reps=10, seed=20260426, sampling='sparse', max_enumeration=1500000, normalize_embedding_rows=True, eigsh_tol=1e-06, rp_oversampling=160, rp_power_iter=4, random_sampling_p=0.7, kmeans_n_init=20)

# %% [markdown]
# ## 실험 실행
#
# 아래 셀을 실행하면 모든 반복을 수행하고 결과 파일을 저장한다.

# %%
outputs = run_named_experiment(sweep='n', method='gaussian_random_projection', show_progress=True)
summary = outputs["summary"]
summary
# Out:
# | [----------------------------------]    1/ 100 (  1.0%) | n=1000 rep=01/10 method=Gaussian random projection | elapsed=00:00 eta=00:56
# / [----------------------------------]    2/ 100 (  2.0%) | n=1000 rep=02/10 method=Gaussian random projection | elapsed=00:01 eta=00:52
# - [#---------------------------------]    3/ 100 (  3.0%) | n=1000 rep=03/10 method=Gaussian random projection | elapsed=00:01 eta=00:49
# \ [#---------------------------------]    4/ 100 (  4.0%) | n=1000 rep=04/10 method=Gaussian random projection | elapsed=00:02 eta=00:50
# | [#---------------------------------]    5/ 100 (  5.0%) | n=1000 rep=05/10 method=Gaussian random projection | elapsed=00:02 eta=00:50
# / [##--------------------------------]    6/ 100 (  6.0%) | n=1000 rep=06/10 method=Gaussian random projection | elapsed=00:03 eta=00:48
# - [##--------------------------------]    7/ 100 (  7.0%) | n=1000 rep=07/10 method=Gaussian random projection | elapsed=00:03 eta=00:47
# \ [##--------------------------------]    8/ 100 (  8.0%) | n=1000 rep=08/10 method=Gaussian random projection | elapsed=00:04 eta=00:47
# | [###-------------------------------]    9/ 100 (  9.0%) | n=1000 rep=09/10 method=Gaussian random projection | elapsed=00:04 eta=00:48
# / [###-------------------------------]   10/ 100 ( 10.0%) | n=1000 rep=10/10 method=Gaussian random projection | elapsed=00:05 eta=00:47
# - [###-------------------------------]   11/ 100 ( 11.0%) | n=2000 rep=01/10 method=Gaussian random projection | elapsed=00:05 eta=00:48
# \ [####------------------------------]   12/ 100 ( 12.0%) | n=2000 rep=02/10 method=Gaussian random projection | elapsed=00:06 eta=00:50
# | [####------------------------------]   13/ 100 ( 13.0%) | n=2000 rep=03/10 method=Gaussian random projection | elapsed=00:07 eta=00:51
# / [####------------------------------]   14/ 100 ( 14.0%) | n=2000 rep=04/10 method=Gaussian random projection | elapsed=00:08 eta=00:52
# - [#####-----------------------------]   15/ 100 ( 15.0%) | n=2000 rep=05/10 method=Gaussian random projection | elapsed=00:09 eta=00:53
# \ [#####-----------------------------]   16/ 100 ( 16.0%) | n=2000 rep=06/10 method=Gaussian random projection | elapsed=00:10 eta=00:53
# | [#####-----------------------------]   17/ 100 ( 17.0%) | n=2000 rep=07/10 method=Gaussian random projection | elapsed=00:11 eta=00:54
# / [######----------------------------]   18/ 100 ( 18.0%) | n=2000 rep=08/10 method=Gaussian random projection | elapsed=00:12 eta=00:55
# - [######----------------------------]   19/ 100 ( 19.0%) | n=2000 rep=09/10 method=Gaussian random projection | elapsed=00:13 eta=00:56
# \ [######----------------------------]   20/ 100 ( 20.0%) | n=2000 rep=10/10 method=Gaussian random projection | elapsed=00:14 eta=00:57
# | [#######---------------------------]   21/ 100 ( 21.0%) | n=3000 rep=01/10 method=Gaussian random projection | elapsed=00:15 eta=00:58
# / [#######---------------------------]   22/ 100 ( 22.0%) | n=3000 rep=02/10 method=Gaussian random projection | elapsed=00:16 eta=00:58
# - [#######---------------------------]   23/ 100 ( 23.0%) | n=3000 rep=03/10 method=Gaussian random projection | elapsed=00:17 eta=00:59
# \ [########--------------------------]   24/ 100 ( 24.0%) | n=3000 rep=04/10 method=Gaussian random projection | elapsed=00:18 eta=00:59
# | [########--------------------------]   25/ 100 ( 25.0%) | n=3000 rep=05/10 method=Gaussian random projection | elapsed=00:19 eta=00:59
# / [########--------------------------]   26/ 100 ( 26.0%) | n=3000 rep=06/10 method=Gaussian random projection | elapsed=00:21 eta=01:01
# - [#########-------------------------]   27/ 100 ( 27.0%) | n=3000 rep=07/10 method=Gaussian random projection | elapsed=00:22 eta=01:02
# \ [#########-------------------------]   28/ 100 ( 28.0%) | n=3000 rep=08/10 method=Gaussian random projection | elapsed=00:24 eta=01:02
# | [#########-------------------------]   29/ 100 ( 29.0%) | n=3000 rep=09/10 method=Gaussian random projection | elapsed=00:25 eta=01:01
# / [##########------------------------]   30/ 100 ( 30.0%) | n=3000 rep=10/10 method=Gaussian random projection | elapsed=00:26 eta=01:01
# - [##########------------------------]   31/ 100 ( 31.0%) | n=4000 rep=01/10 method=Gaussian random projection | elapsed=00:27 eta=01:02
# \ [##########------------------------]   32/ 100 ( 32.0%) | n=4000 rep=02/10 method=Gaussian random projection | elapsed=00:29 eta=01:02
# | [###########-----------------------]   33/ 100 ( 33.0%) | n=4000 rep=03/10 method=Gaussian random projection | elapsed=00:30 eta=01:02
# / [###########-----------------------]   34/ 100 ( 34.0%) | n=4000 rep=04/10 method=Gaussian random projection | elapsed=00:32 eta=01:02
# - [###########-----------------------]   35/ 100 ( 35.0%) | n=4000 rep=05/10 method=Gaussian random projection | elapsed=00:33 eta=01:02
# \ [############----------------------]   36/ 100 ( 36.0%) | n=4000 rep=06/10 method=Gaussian random projection | elapsed=00:34 eta=01:02
# | [############----------------------]   37/ 100 ( 37.0%) | n=4000 rep=07/10 method=Gaussian random projection | elapsed=00:36 eta=01:01
# / [############----------------------]   38/ 100 ( 38.0%) | n=4000 rep=08/10 method=Gaussian random projection | elapsed=00:38 eta=01:02
# - [#############---------------------]   39/ 100 ( 39.0%) | n=4000 rep=09/10 method=Gaussian random projection | elapsed=00:39 eta=01:01
# \ [#############---------------------]   40/ 100 ( 40.0%) | n=4000 rep=10/10 method=Gaussian random projection | elapsed=00:40 eta=01:00
# | [#############---------------------]   41/ 100 ( 41.0%) | n=5000 rep=01/10 method=Gaussian random projection | elapsed=00:42 eta=01:00
# / [##############--------------------]   42/ 100 ( 42.0%) | n=5000 rep=02/10 method=Gaussian random projection | elapsed=00:43 eta=01:00
# - [##############--------------------]   43/ 100 ( 43.0%) | n=5000 rep=03/10 method=Gaussian random projection | elapsed=00:45 eta=00:59
# \ [##############--------------------]   44/ 100 ( 44.0%) | n=5000 rep=04/10 method=Gaussian random projection | elapsed=00:46 eta=00:59
# | [###############-------------------]   45/ 100 ( 45.0%) | n=5000 rep=05/10 method=Gaussian random projection | elapsed=00:48 eta=00:58
# / [###############-------------------]   46/ 100 ( 46.0%) | n=5000 rep=06/10 method=Gaussian random projection | elapsed=00:49 eta=00:58
# - [###############-------------------]   47/ 100 ( 47.0%) | n=5000 rep=07/10 method=Gaussian random projection | elapsed=00:51 eta=00:57
# \ [################------------------]   48/ 100 ( 48.0%) | n=5000 rep=08/10 method=Gaussian random projection | elapsed=00:52 eta=00:57
# | [################------------------]   49/ 100 ( 49.0%) | n=5000 rep=09/10 method=Gaussian random projection | elapsed=00:54 eta=00:56
# / [#################-----------------]   50/ 100 ( 50.0%) | n=5000 rep=10/10 method=Gaussian random projection | elapsed=00:55 eta=00:55
# - [#################-----------------]   51/ 100 ( 51.0%) | n=6000 rep=01/10 method=Gaussian random projection | elapsed=00:57 eta=00:55
# \ [#################-----------------]   52/ 100 ( 52.0%) | n=6000 rep=02/10 method=Gaussian random projection | elapsed=00:59 eta=00:54
# | [##################----------------]   53/ 100 ( 53.0%) | n=6000 rep=03/10 method=Gaussian random projection | elapsed=01:01 eta=00:54
# / [##################----------------]   54/ 100 ( 54.0%) | n=6000 rep=04/10 method=Gaussian random projection | elapsed=01:03 eta=00:53
# - [##################----------------]   55/ 100 ( 55.0%) | n=6000 rep=05/10 method=Gaussian random projection | elapsed=01:05 eta=00:53
# \ [###################---------------]   56/ 100 ( 56.0%) | n=6000 rep=06/10 method=Gaussian random projection | elapsed=01:06 eta=00:52
# | [###################---------------]   57/ 100 ( 57.0%) | n=6000 rep=07/10 method=Gaussian random projection | elapsed=01:08 eta=00:51
# / [###################---------------]   58/ 100 ( 58.0%) | n=6000 rep=08/10 method=Gaussian random projection | elapsed=01:10 eta=00:50
# - [####################--------------]   59/ 100 ( 59.0%) | n=6000 rep=09/10 method=Gaussian random projection | elapsed=01:12 eta=00:50
# \ [####################--------------]   60/ 100 ( 60.0%) | n=6000 rep=10/10 method=Gaussian random projection | elapsed=01:13 eta=00:49
# | [####################--------------]   61/ 100 ( 61.0%) | n=7000 rep=01/10 method=Gaussian random projection | elapsed=01:16 eta=00:48
# / [#####################-------------]   62/ 100 ( 62.0%) | n=7000 rep=02/10 method=Gaussian random projection | elapsed=01:18 eta=00:47
# - [#####################-------------]   63/ 100 ( 63.0%) | n=7000 rep=03/10 method=Gaussian random projection | elapsed=01:20 eta=00:47
# \ [#####################-------------]   64/ 100 ( 64.0%) | n=7000 rep=04/10 method=Gaussian random projection | elapsed=01:22 eta=00:46
# | [######################------------]   65/ 100 ( 65.0%) | n=7000 rep=05/10 method=Gaussian random projection | elapsed=01:24 eta=00:45
# / [######################------------]   66/ 100 ( 66.0%) | n=7000 rep=06/10 method=Gaussian random projection | elapsed=01:26 eta=00:44
# - [######################------------]   67/ 100 ( 67.0%) | n=7000 rep=07/10 method=Gaussian random projection | elapsed=01:28 eta=00:43
# \ [#######################-----------]   68/ 100 ( 68.0%) | n=7000 rep=08/10 method=Gaussian random projection | elapsed=01:30 eta=00:42
# | [#######################-----------]   69/ 100 ( 69.0%) | n=7000 rep=09/10 method=Gaussian random projection | elapsed=01:32 eta=00:41
# / [#######################-----------]   70/ 100 ( 70.0%) | n=7000 rep=10/10 method=Gaussian random projection | elapsed=01:34 eta=00:40
# - [########################----------]   71/ 100 ( 71.0%) | n=8000 rep=01/10 method=Gaussian random projection | elapsed=01:36 eta=00:39
# \ [########################----------]   72/ 100 ( 72.0%) | n=8000 rep=02/10 method=Gaussian random projection | elapsed=01:39 eta=00:38
# | [########################----------]   73/ 100 ( 73.0%) | n=8000 rep=03/10 method=Gaussian random projection | elapsed=01:41 eta=00:37
# / [#########################---------]   74/ 100 ( 74.0%) | n=8000 rep=04/10 method=Gaussian random projection | elapsed=01:44 eta=00:36
# - [#########################---------]   75/ 100 ( 75.0%) | n=8000 rep=05/10 method=Gaussian random projection | elapsed=01:47 eta=00:35
# \ [#########################---------]   76/ 100 ( 76.0%) | n=8000 rep=06/10 method=Gaussian random projection | elapsed=01:49 eta=00:34
# | [##########################--------]   77/ 100 ( 77.0%) | n=8000 rep=07/10 method=Gaussian random projection | elapsed=01:52 eta=00:33
# / [##########################--------]   78/ 100 ( 78.0%) | n=8000 rep=08/10 method=Gaussian random projection | elapsed=01:54 eta=00:32
# - [##########################--------]   79/ 100 ( 79.0%) | n=8000 rep=09/10 method=Gaussian random projection | elapsed=01:56 eta=00:31
# \ [###########################-------]   80/ 100 ( 80.0%) | n=8000 rep=10/10 method=Gaussian random projection | elapsed=01:59 eta=00:29
# | [###########################-------]   81/ 100 ( 81.0%) | n=9000 rep=01/10 method=Gaussian random projection | elapsed=02:02 eta=00:28
# / [###########################-------]   82/ 100 ( 82.0%) | n=9000 rep=02/10 method=Gaussian random projection | elapsed=02:05 eta=00:27
# - [############################------]   83/ 100 ( 83.0%) | n=9000 rep=03/10 method=Gaussian random projection | elapsed=02:08 eta=00:26
# \ [############################------]   84/ 100 ( 84.0%) | n=9000 rep=04/10 method=Gaussian random projection | elapsed=02:10 eta=00:24
# | [############################------]   85/ 100 ( 85.0%) | n=9000 rep=05/10 method=Gaussian random projection | elapsed=02:13 eta=00:23
# / [#############################-----]   86/ 100 ( 86.0%) | n=9000 rep=06/10 method=Gaussian random projection | elapsed=02:15 eta=00:22
# - [#############################-----]   87/ 100 ( 87.0%) | n=9000 rep=07/10 method=Gaussian random projection | elapsed=02:18 eta=00:20
# \ [#############################-----]   88/ 100 ( 88.0%) | n=9000 rep=08/10 method=Gaussian random projection | elapsed=02:20 eta=00:19
# | [##############################----]   89/ 100 ( 89.0%) | n=9000 rep=09/10 method=Gaussian random projection | elapsed=02:23 eta=00:17
# / [##############################----]   90/ 100 ( 90.0%) | n=9000 rep=10/10 method=Gaussian random projection | elapsed=02:26 eta=00:16
# - [##############################----]   91/ 100 ( 91.0%) | n=10000 rep=01/10 method=Gaussian random projection | elapsed=02:29 eta=00:14
# \ [###############################---]   92/ 100 ( 92.0%) | n=10000 rep=02/10 method=Gaussian random projection | elapsed=02:32 eta=00:13
# | [###############################---]   93/ 100 ( 93.0%) | n=10000 rep=03/10 method=Gaussian random projection | elapsed=02:35 eta=00:11
# / [###############################---]   94/ 100 ( 94.0%) | n=10000 rep=04/10 method=Gaussian random projection | elapsed=02:38 eta=00:10
# - [################################--]   95/ 100 ( 95.0%) | n=10000 rep=05/10 method=Gaussian random projection | elapsed=02:41 eta=00:08
# \ [################################--]   96/ 100 ( 96.0%) | n=10000 rep=06/10 method=Gaussian random projection | elapsed=02:44 eta=00:06
# | [################################--]   97/ 100 ( 97.0%) | n=10000 rep=07/10 method=Gaussian random projection | elapsed=02:47 eta=00:05
# / [#################################-]   98/ 100 ( 98.0%) | n=10000 rep=08/10 method=Gaussian random projection | elapsed=02:50 eta=00:03
# - [#################################-]   99/ 100 ( 99.0%) | n=10000 rep=09/10 method=Gaussian random projection | elapsed=02:52 eta=00:01
# \ [##################################]  100/ 100 (100.0%) | n=10000 rep=10/10 method=Gaussian random projection | elapsed=02:56 eta=00:00
#        n                      method  reps  num_hyperedges_total_mean  num_hyperedges_total_std  hypergraph_degree_mean_mean  hypergraph_degree_mean_std  hypergraph_degree_max_mean  hypergraph_degree_max_std  \
# 0   1000  Gaussian random projection    10                     5012.9                 71.630921                    15.038700                    0.214893                        28.8                   2.573368
# 1   2000  Gaussian random projection    10                    10065.6                 79.514080                    15.098400                    0.119271                        29.8                   1.398412
# 2   3000  Gaussian random projection    10                    15109.4                150.356022                    15.109400                    0.150356                        30.4                   1.837873
# 3   4000  Gaussian random projection    10                    20159.4                118.558190                    15.119550                    0.088919                        30.5                   1.080123
# 4   5000  Gaussian random projection    10                    25181.6                189.619619                    15.108960                    0.113772                        30.9                   2.330951
# 5   6000  Gaussian random projection    10                    30186.8                271.925153                    15.093400                    0.135963                        31.0                   1.054093
# 6   7000  Gaussian random projection    10                    35245.9                252.998221                    15.105386                    0.108428                        32.7                   1.702939
# 7   8000  Gaussian random projection    10                    40249.8                259.310110                    15.093675                    0.097241                        32.1                   1.449138
# 8   9000  Gaussian random projection    10                    45343.4                252.376791                    15.114467                    0.084126                        31.4                   0.516398
# 9  10000  Gaussian random projection    10                    50329.3                271.344410                    15.098790                    0.081403                        31.4                   1.074968
#
#    expected_degree_mean_mean  expected_degree_mean_std  candidate_within_fraction_mean  candidate_within_fraction_std  isolated_fraction_mean  isolated_fraction_std  misclassification_mean  misclassification_std  \
# 0                  15.023298                       0.0                        0.110445                            0.0                0.000000               0.000000                0.017000               0.004422
# 1                  15.067158                       0.0                        0.110778                            0.0                0.000000               0.000000                0.017100               0.001926
# 2                  15.081794                       0.0                        0.110889                            0.0                0.000000               0.000000                0.023200               0.001657
# 3                  15.089123                       0.0                        0.110944                            0.0                0.000000               0.000000                0.021850               0.002328
# 4                  15.093519                       0.0                        0.110978                            0.0                0.000000               0.000000                0.022100               0.002708
# 5                  15.096448                       0.0                        0.111000                            0.0                0.000017               0.000053                0.025400               0.002639
# 6                  15.098543                       0.0                        0.111016                            0.0                0.000000               0.000000                0.031100               0.003745
# 7                  15.100114                       0.0                        0.111028                            0.0                0.000000               0.000000                0.031512               0.002906
# 8                  15.101335                       0.0                        0.111037                            0.0                0.000000               0.000000                0.035622               0.002455
# 9                  15.102313                       0.0                        0.111044                            0.0                0.000000               0.000000                0.037110               0.003653
#
#    ARI_mean   ARI_std  NMI_mean   NMI_std  generation_wall_sec_mean  generation_wall_sec_std  zhou_theta_build_wall_sec_mean  zhou_theta_build_wall_sec_std  eigen_decomposition_wall_sec_mean  \
# 0  0.949625  0.012913  0.913963  0.019456                  0.173282                 0.012365                        0.013397                       0.000534                           0.058600
# 1  0.949333  0.005637  0.911883  0.007988                  0.341007                 0.009170                        0.024267                       0.000962                           0.155786
# 2  0.931592  0.004802  0.885713  0.006614                  0.516147                 0.028558                        0.036846                       0.001261                           0.181481
# 3  0.935522  0.006752  0.891232  0.009384                  0.691025                 0.076356                        0.048428                       0.002792                           0.205443
# 4  0.934801  0.007830  0.890217  0.010931                  0.809374                 0.014003                        0.058368                       0.001960                           0.183575
# 5  0.925259  0.007609  0.876924  0.010303                  0.986174                 0.031710                        0.070158                       0.001687                           0.195298
# 6  0.908895  0.010719  0.854975  0.013994                  1.120639                 0.017490                        0.080467                       0.001142                           0.227279
# 7  0.907694  0.008281  0.853117  0.010810                  1.334651                 0.064953                        0.094075                       0.004430                           0.370081
# 8  0.895992  0.006973  0.837971  0.008961                  1.496431                 0.073920                        0.106041                       0.004075                           0.382767
# 9  0.891784  0.010349  0.832571  0.013146                  1.658436                 0.054573                        0.118036                       0.003318                           0.457892
#
#    eigen_decomposition_wall_sec_std  embedding_normalize_wall_sec_mean  embedding_normalize_wall_sec_std  kmeans_wall_sec_mean  kmeans_wall_sec_std  spectral_clustering_wall_sec_mean  spectral_clustering_wall_sec_std  \
# 0                          0.009027                           0.000223                          0.000248              0.121650             0.046747                           0.180478                          0.047360
# 1                          0.113084                           0.000935                          0.001899              0.245715             0.048514                           0.402443                          0.125268
# 2                          0.151323                           0.000437                          0.000510              0.264292             0.031146                           0.446217                          0.166268
# 3                          0.099149                           0.000742                          0.000969              0.215041             0.068620                           0.421232                          0.113996
# 4                          0.031566                           0.000589                          0.000453              0.191040             0.040614                           0.375211                          0.054515
# 5                          0.027849                           0.000404                          0.000207              0.246962             0.054279                           0.442669                          0.045015
# 6                          0.036647                           0.000565                          0.000385              0.242418             0.036750                           0.470268                          0.059501
# 7                          0.226434                           0.000369                          0.000179              0.270887             0.030829                           0.641343                          0.235952
# 8                          0.230056                           0.000333                          0.000146              0.246400             0.053094                           0.629506                          0.259958
# 9                          0.275676                           0.000460                          0.000436              0.262917             0.044970                           0.721315                          0.308503
#
#    metric_wall_sec_mean  metric_wall_sec_std  algorithm_total_wall_sec_mean  algorithm_total_wall_sec_std  cpu_time_sec_mean  cpu_time_sec_std  wall_clock_sec_mean  wall_clock_sec_std  peak_traced_memory_mb_mean  \
# 0              0.012307             0.009294                       0.367152                      0.045423           2.505314          0.378663             0.449117            0.057026                    7.191244
# 1              0.010524             0.002351                       0.767711                      0.129664           4.639581          0.951065             0.867218            0.132518                   14.111719
# 2              0.013656             0.001642                       0.999203                      0.171494           5.303444          1.232300             1.146656            0.175994                   21.033210
# 3              0.019534             0.004940                       1.160679                      0.149273           5.370226          0.720247             1.369276            0.143427                   27.956430
# 4              0.027074             0.004445                       1.242946                      0.063240           5.300464          0.323514             1.489993            0.056511                   34.867986
# 5              0.026141             0.005247                       1.498996                      0.062526           5.959671          0.361888             1.772420            0.058026                   41.774800
# 6              0.029585             0.006732                       1.671368                      0.064743           6.269621          0.396256             1.994570            0.074797                   48.700020
# 7              0.029118             0.004840                       2.070063                      0.287714           7.393522          1.070046             2.438814            0.312216                   55.606796
# 8              0.036382             0.007192                       2.231971                      0.325503           7.441463          1.325668             2.640427            0.331380                   62.546421
# 9              0.040827             0.007419                       2.497741                      0.331794           8.076120          2.012288             2.966236            0.331991                   69.446766
#
#    peak_traced_memory_mb_std  rss_delta_mb_mean  rss_delta_mb_std  rp_draw_omega_sec_mean  rp_draw_omega_sec_std  rp_power_iter_sec_mean  rp_power_iter_sec_std  rp_qr_sec_mean  rp_qr_sec_std  rp_build_core_sec_mean  \
# 0                   0.023130           5.273438          5.750218                0.000673               0.000035                0.008439               0.000244        0.034409       0.008622                0.005869
# 1                   0.028233           5.073437          4.028814                0.001381               0.000092                0.018844               0.000818        0.102353       0.098340                0.008875
# 2                   0.053284           3.776562          8.257234                0.002106               0.000112                0.030187               0.001595        0.119618       0.131559                0.012788
# 3                   0.043627          -2.015625         20.047870                0.002744               0.000087                0.042634               0.005630        0.130815       0.093856                0.014331
# 4                   0.067511           5.664062          9.024842                0.003344               0.000070                0.052794               0.003898        0.094875       0.024112                0.022417
# 5                   0.099116           0.325000         29.665014                0.004027               0.000089                0.065216               0.004211        0.092780       0.019260                0.023769
# 6                   0.092966           3.581250         12.444246                0.004674               0.000155                0.081868               0.006366        0.100641       0.020975                0.030892
# 7                   0.094897          -9.910937         32.867704                0.005353               0.000104                0.104143               0.015239        0.197422       0.195646                0.047249
# 8                   0.091457           4.096875          8.305134                0.005580               0.000409                0.137335               0.035789        0.175409       0.158277                0.052118
# 9                   0.098043          -1.384375         20.325522                0.006100               0.000101                0.175222               0.040266        0.203852       0.203894                0.056341
#
#    rp_build_core_sec_std  rp_small_eig_sec_mean  rp_small_eig_sec_std  rp_lift_sec_mean  rp_lift_sec_std  top_eigenvalue_max_mean  top_eigenvalue_max_std  top_eigenvalue_min_mean  top_eigenvalue_min_std
# 0               0.002328               0.008799              0.003905          0.000232         0.000186                 0.999999            1.550271e-07                 0.688910                0.004667
# 1               0.003370               0.022838              0.021690          0.000776         0.001053                 0.999995            9.150543e-07                 0.691458                0.003185
# 2               0.004279               0.015568              0.018298          0.000333         0.000263                 0.999991            1.289486e-06                 0.689736                0.002607
# 3               0.005152               0.012978              0.008761          0.000760         0.000819                 0.999985            1.474038e-06                 0.688273                0.002124
# 4               0.009719               0.008427              0.002798          0.000820         0.000748                 0.999979            4.632320e-06                 0.690923                0.002934
# 5               0.008819               0.007903              0.002366          0.000517         0.000340                 0.999972            4.869951e-06                 0.687789                0.004260
# 6               0.014372               0.007516              0.001561          0.000777         0.000570                 0.999964            5.371829e-06                 0.684892                0.002692
# 7               0.017052               0.013551              0.016527          0.001402         0.001422                 0.999961            5.673275e-06                 0.684202                0.003140
# 8               0.026337               0.010079              0.015993          0.001339         0.001439                 0.999955            6.836650e-06                 0.682536                0.001400
# 9               0.026592               0.013967              0.016735          0.001597         0.001754                 0.999947            4.848088e-06                 0.681171                0.002038

# %% [markdown]
# ## 저장된 파일
#
# 실험이 끝나면 아래 경로에 raw 결과, summary 결과, 설정 파일, 요약 그림이 저장된다.

# %%
outputs["paths"]
# Out:
# {'raw': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection_raw.csv'),
#  'summary': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection_summary.csv'),
#  'config': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection_config.json'),
#  'plot': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection/EXP-20260428-003_uniform_hsbm_n_scaling_gaussian_random_projection_summary.png')}
