# %% [markdown]
# # 균일 HSBM K 변화 - 가우시안 랜덤 프로젝션
#
# 이 노트북은 균일 HSBM의 `K` 변화 실험을 `가우시안 랜덤 프로젝션` 방식으로 실행한다.
#
# 가우시안 랜덤 프로젝션은 `Theta`에 Gaussian test matrix를 곱해 낮은 차원의 부분공간을 만든 뒤, 작은 core matrix의 고유벡터를 원래 공간으로 lift한다.
#
# 하이퍼그래프 생성식은 기존 비랜덤 실험과 동일하게 `p_in = a_in * rho_n / n ** (m - 1)`, `p_out = b_out * rho_n / n ** (m - 1)`를 사용한다.

# %% [markdown]
# ## 실행 설정
#
# 공통 실행 코드는 `uniform_hsbm_randomized.py`에 두었다. 이 노트북은 해당 실행기를 호출하고, raw CSV, summary CSV, 설정 JSON, 요약 그림을 `results/` 아래에 저장한다.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "src" / "common.py").exists():
        PROJECT_ROOT = candidate
        break

EXPERIMENT_DIR = PROJECT_ROOT / "experiments" / "균일 HSBM 실험"
if str(EXPERIMENT_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENT_DIR))

from uniform_hsbm_randomized import resolve_spec, run_named_experiment

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)
SPEC = resolve_spec(sweep='K', method='gaussian_random_projection')
SPEC
# Out:
# SweepSpec(sweep='K', method='gaussian_random_projection', experiment_id='EXP-20260428-001', experiment_slug='uniform_hsbm_K_sweep_gaussian_random_projection', notebook_name='K변화_gaussian_random_projection.ipynb', title_ko='균일 HSBM K 변화 - 가우시안 랜덤 프로젝션', x_col='K', x_values=(2, 3, 4, 5, 6, 8, 10, 12), n=5000, K=None, m=3, a_in=36.0, b_out=4.0, rho_n=4.0, reps=10, seed=20260427, sampling='sparse', max_enumeration=1500000, normalize_embedding_rows=True, eigsh_tol=1e-06, rp_oversampling=160, rp_power_iter=4, random_sampling_p=0.7, kmeans_n_init=20)

# %% [markdown]
# ## 실험 실행
#
# 아래 셀을 실행하면 모든 반복을 수행하고 결과 파일을 저장한다.

# %%
outputs = run_named_experiment(sweep='K', method='gaussian_random_projection', show_progress=True)
summary = outputs["summary"]
summary
# Out:
# | [----------------------------------]    1/  80 (  1.2%) | K=2 rep=01/10 method=Gaussian random projection | elapsed=00:02 eta=03:09
# / [----------------------------------]    2/  80 (  2.5%) | K=2 rep=02/10 method=Gaussian random projection | elapsed=00:04 eta=02:50
# - [#---------------------------------]    3/  80 (  3.8%) | K=2 rep=03/10 method=Gaussian random projection | elapsed=00:06 eta=02:44
# \ [#---------------------------------]    4/  80 (  5.0%) | K=2 rep=04/10 method=Gaussian random projection | elapsed=00:08 eta=02:41
# | [##--------------------------------]    5/  80 (  6.2%) | K=2 rep=05/10 method=Gaussian random projection | elapsed=00:10 eta=02:39
# / [##--------------------------------]    6/  80 (  7.5%) | K=2 rep=06/10 method=Gaussian random projection | elapsed=00:12 eta=02:34
# - [##--------------------------------]    7/  80 (  8.8%) | K=2 rep=07/10 method=Gaussian random projection | elapsed=00:14 eta=02:31
# \ [###-------------------------------]    8/  80 ( 10.0%) | K=2 rep=08/10 method=Gaussian random projection | elapsed=00:16 eta=02:27
# | [###-------------------------------]    9/  80 ( 11.2%) | K=2 rep=09/10 method=Gaussian random projection | elapsed=00:18 eta=02:25
# / [####------------------------------]   10/  80 ( 12.5%) | K=2 rep=10/10 method=Gaussian random projection | elapsed=00:20 eta=02:22
# - [####------------------------------]   11/  80 ( 13.8%) | K=3 rep=01/10 method=Gaussian random projection | elapsed=00:21 eta=02:16
# \ [#####-----------------------------]   12/  80 ( 15.0%) | K=3 rep=02/10 method=Gaussian random projection | elapsed=00:23 eta=02:11
# | [#####-----------------------------]   13/  80 ( 16.2%) | K=3 rep=03/10 method=Gaussian random projection | elapsed=00:24 eta=02:07
# / [#####-----------------------------]   14/  80 ( 17.5%) | K=3 rep=04/10 method=Gaussian random projection | elapsed=00:26 eta=02:03
# - [######----------------------------]   15/  80 ( 18.8%) | K=3 rep=05/10 method=Gaussian random projection | elapsed=00:27 eta=01:59
# \ [######----------------------------]   16/  80 ( 20.0%) | K=3 rep=06/10 method=Gaussian random projection | elapsed=00:29 eta=01:56
# | [#######---------------------------]   17/  80 ( 21.2%) | K=3 rep=07/10 method=Gaussian random projection | elapsed=00:30 eta=01:53
# / [#######---------------------------]   18/  80 ( 22.5%) | K=3 rep=08/10 method=Gaussian random projection | elapsed=00:32 eta=01:50
# - [########--------------------------]   19/  80 ( 23.8%) | K=3 rep=09/10 method=Gaussian random projection | elapsed=00:33 eta=01:47
# \ [########--------------------------]   20/  80 ( 25.0%) | K=3 rep=10/10 method=Gaussian random projection | elapsed=00:35 eta=01:45
# | [########--------------------------]   21/  80 ( 26.2%) | K=4 rep=01/10 method=Gaussian random projection | elapsed=00:36 eta=01:41
# / [#########-------------------------]   22/  80 ( 27.5%) | K=4 rep=02/10 method=Gaussian random projection | elapsed=00:38 eta=01:41
# - [#########-------------------------]   23/  80 ( 28.7%) | K=4 rep=03/10 method=Gaussian random projection | elapsed=00:39 eta=01:38
# \ [##########------------------------]   24/  80 ( 30.0%) | K=4 rep=04/10 method=Gaussian random projection | elapsed=00:41 eta=01:36
# | [##########------------------------]   25/  80 ( 31.2%) | K=4 rep=05/10 method=Gaussian random projection | elapsed=00:43 eta=01:34
# / [###########-----------------------]   26/  80 ( 32.5%) | K=4 rep=06/10 method=Gaussian random projection | elapsed=00:44 eta=01:33
# - [###########-----------------------]   27/  80 ( 33.8%) | K=4 rep=07/10 method=Gaussian random projection | elapsed=00:46 eta=01:31
# \ [###########-----------------------]   28/  80 ( 35.0%) | K=4 rep=08/10 method=Gaussian random projection | elapsed=00:48 eta=01:29
# | [############----------------------]   29/  80 ( 36.2%) | K=4 rep=09/10 method=Gaussian random projection | elapsed=00:49 eta=01:27
# / [############----------------------]   30/  80 ( 37.5%) | K=4 rep=10/10 method=Gaussian random projection | elapsed=00:51 eta=01:25
# - [#############---------------------]   31/  80 ( 38.8%) | K=5 rep=01/10 method=Gaussian random projection | elapsed=00:52 eta=01:23
# \ [#############---------------------]   32/  80 ( 40.0%) | K=5 rep=02/10 method=Gaussian random projection | elapsed=00:54 eta=01:21
# | [##############--------------------]   33/  80 ( 41.2%) | K=5 rep=03/10 method=Gaussian random projection | elapsed=00:56 eta=01:19
# / [##############--------------------]   34/  80 ( 42.5%) | K=5 rep=04/10 method=Gaussian random projection | elapsed=00:57 eta=01:18
# - [##############--------------------]   35/  80 ( 43.8%) | K=5 rep=05/10 method=Gaussian random projection | elapsed=00:59 eta=01:16
# \ [###############-------------------]   36/  80 ( 45.0%) | K=5 rep=06/10 method=Gaussian random projection | elapsed=01:01 eta=01:15
# | [###############-------------------]   37/  80 ( 46.2%) | K=5 rep=07/10 method=Gaussian random projection | elapsed=01:03 eta=01:13
# / [################------------------]   38/  80 ( 47.5%) | K=5 rep=08/10 method=Gaussian random projection | elapsed=01:05 eta=01:12
# - [################------------------]   39/  80 ( 48.8%) | K=5 rep=09/10 method=Gaussian random projection | elapsed=01:07 eta=01:11
# \ [#################-----------------]   40/  80 ( 50.0%) | K=5 rep=10/10 method=Gaussian random projection | elapsed=01:09 eta=01:09
# | [#################-----------------]   41/  80 ( 51.2%) | K=6 rep=01/10 method=Gaussian random projection | elapsed=01:11 eta=01:07
# / [#################-----------------]   42/  80 ( 52.5%) | K=6 rep=02/10 method=Gaussian random projection | elapsed=01:12 eta=01:05
# - [##################----------------]   43/  80 ( 53.8%) | K=6 rep=03/10 method=Gaussian random projection | elapsed=01:14 eta=01:04
# \ [##################----------------]   44/  80 ( 55.0%) | K=6 rep=04/10 method=Gaussian random projection | elapsed=01:16 eta=01:02
# | [###################---------------]   45/  80 ( 56.2%) | K=6 rep=05/10 method=Gaussian random projection | elapsed=01:17 eta=01:00
# / [###################---------------]   46/  80 ( 57.5%) | K=6 rep=06/10 method=Gaussian random projection | elapsed=01:19 eta=00:58
# - [###################---------------]   47/  80 ( 58.8%) | K=6 rep=07/10 method=Gaussian random projection | elapsed=01:21 eta=00:56
# \ [####################--------------]   48/  80 ( 60.0%) | K=6 rep=08/10 method=Gaussian random projection | elapsed=01:22 eta=00:55
# | [####################--------------]   49/  80 ( 61.3%) | K=6 rep=09/10 method=Gaussian random projection | elapsed=01:24 eta=00:53
# / [#####################-------------]   50/  80 ( 62.5%) | K=6 rep=10/10 method=Gaussian random projection | elapsed=01:25 eta=00:51
# - [#####################-------------]   51/  80 ( 63.7%) | K=8 rep=01/10 method=Gaussian random projection | elapsed=01:27 eta=00:49
# \ [######################------------]   52/  80 ( 65.0%) | K=8 rep=02/10 method=Gaussian random projection | elapsed=01:28 eta=00:47
# | [######################------------]   53/  80 ( 66.2%) | K=8 rep=03/10 method=Gaussian random projection | elapsed=01:30 eta=00:46
# / [######################------------]   54/  80 ( 67.5%) | K=8 rep=04/10 method=Gaussian random projection | elapsed=01:32 eta=00:44
# - [#######################-----------]   55/  80 ( 68.8%) | K=8 rep=05/10 method=Gaussian random projection | elapsed=01:33 eta=00:42
# \ [#######################-----------]   56/  80 ( 70.0%) | K=8 rep=06/10 method=Gaussian random projection | elapsed=01:35 eta=00:40
# | [########################----------]   57/  80 ( 71.2%) | K=8 rep=07/10 method=Gaussian random projection | elapsed=01:37 eta=00:39
# / [########################----------]   58/  80 ( 72.5%) | K=8 rep=08/10 method=Gaussian random projection | elapsed=01:38 eta=00:37
# - [#########################---------]   59/  80 ( 73.8%) | K=8 rep=09/10 method=Gaussian random projection | elapsed=01:40 eta=00:35
# \ [#########################---------]   60/  80 ( 75.0%) | K=8 rep=10/10 method=Gaussian random projection | elapsed=01:42 eta=00:34
# | [#########################---------]   61/  80 ( 76.2%) | K=10 rep=01/10 method=Gaussian random projection | elapsed=01:44 eta=00:32
# / [##########################--------]   62/  80 ( 77.5%) | K=10 rep=02/10 method=Gaussian random projection | elapsed=01:45 eta=00:30
# - [##########################--------]   63/  80 ( 78.8%) | K=10 rep=03/10 method=Gaussian random projection | elapsed=01:47 eta=00:29
# \ [###########################-------]   64/  80 ( 80.0%) | K=10 rep=04/10 method=Gaussian random projection | elapsed=01:49 eta=00:27
# | [###########################-------]   65/  80 ( 81.2%) | K=10 rep=05/10 method=Gaussian random projection | elapsed=01:51 eta=00:25
# / [############################------]   66/  80 ( 82.5%) | K=10 rep=06/10 method=Gaussian random projection | elapsed=01:52 eta=00:23
# - [############################------]   67/  80 ( 83.8%) | K=10 rep=07/10 method=Gaussian random projection | elapsed=01:54 eta=00:22
# \ [############################------]   68/  80 ( 85.0%) | K=10 rep=08/10 method=Gaussian random projection | elapsed=01:56 eta=00:20
# | [#############################-----]   69/  80 ( 86.2%) | K=10 rep=09/10 method=Gaussian random projection | elapsed=01:57 eta=00:18
# / [#############################-----]   70/  80 ( 87.5%) | K=10 rep=10/10 method=Gaussian random projection | elapsed=01:59 eta=00:17
# - [##############################----]   71/  80 ( 88.8%) | K=12 rep=01/10 method=Gaussian random projection | elapsed=02:01 eta=00:15
# \ [##############################----]   72/  80 ( 90.0%) | K=12 rep=02/10 method=Gaussian random projection | elapsed=02:02 eta=00:13
# | [###############################---]   73/  80 ( 91.2%) | K=12 rep=03/10 method=Gaussian random projection | elapsed=02:05 eta=00:12
# / [###############################---]   74/  80 ( 92.5%) | K=12 rep=04/10 method=Gaussian random projection | elapsed=02:07 eta=00:10
# - [###############################---]   75/  80 ( 93.8%) | K=12 rep=05/10 method=Gaussian random projection | elapsed=02:08 eta=00:08
# \ [################################--]   76/  80 ( 95.0%) | K=12 rep=06/10 method=Gaussian random projection | elapsed=02:10 eta=00:06
# | [################################--]   77/  80 ( 96.2%) | K=12 rep=07/10 method=Gaussian random projection | elapsed=02:13 eta=00:05
# / [#################################-]   78/  80 ( 97.5%) | K=12 rep=08/10 method=Gaussian random projection | elapsed=02:14 eta=00:03
# - [#################################-]   79/  80 ( 98.8%) | K=12 rep=09/10 method=Gaussian random projection | elapsed=02:16 eta=00:01
# \ [##################################]   80/  80 (100.0%) | K=12 rep=10/10 method=Gaussian random projection | elapsed=02:18 eta=00:00
#     K                      method  reps  num_hyperedges_total_mean  num_hyperedges_total_std  hypergraph_degree_mean_mean  hypergraph_degree_mean_std  hypergraph_degree_max_mean  hypergraph_degree_max_std  \
# 0   2  Gaussian random projection    10                    39967.1                171.798622                     23.98026                    0.103079                        43.6                   1.712698
# 1   3  Gaussian random projection    10                    25078.4                 71.963262                     15.04704                    0.043178                        31.2                   1.549193
# 2   4  Gaussian random projection    10                    20063.4                134.258623                     12.03804                    0.080555                        26.8                   1.398412
# 3   5  Gaussian random projection    10                    17566.3                110.380202                     10.53978                    0.066228                        24.3                   1.418136
# 4   6  Gaussian random projection    10                    16276.3                105.995859                      9.76578                    0.063598                        23.4                   0.966092
# 5   8  Gaussian random projection    10                    14983.1                 91.676303                      8.98986                    0.055006                        21.9                   0.737865
# 6  10  Gaussian random projection    10                    14361.5                109.482875                      8.61690                    0.065690                        21.0                   1.154701
# 7  12  Gaussian random projection    10                    14093.9                102.474333                      8.45634                    0.061485                        21.3                   1.337494
#
#    expected_degree_mean_mean  expected_degree_mean_std  candidate_within_fraction_mean  candidate_within_fraction_std  isolated_fraction_mean  isolated_fraction_std  misclassification_mean  misclassification_std  \
# 0                  23.976006                       0.0                        0.249850                            0.0                 0.00000               0.000000                 0.00004               0.000126
# 1                  15.093519                       0.0                        0.110978                            0.0                 0.00000               0.000000                 0.02412               0.002518
# 2                  11.985606                       0.0                        0.062388                            0.0                 0.00000               0.000000                 0.23910               0.010112
# 3                  10.547526                       0.0                        0.039904                            0.0                 0.00004               0.000084                 0.68208               0.015248
# 4                   9.766585                       0.0                        0.027694                            0.0                 0.00002               0.000063                 0.80036               0.006927
# 5                   8.990406                       0.0                        0.015559                            0.0                 0.00016               0.000207                 0.85096               0.004008
# 6                   8.631366                       0.0                        0.009946                            0.0                 0.00028               0.000169                 0.87710               0.003316
# 7                   8.436452                       0.0                        0.006899                            0.0                 0.00018               0.000199                 0.89324               0.002343
#
#    ARI_mean   ARI_std  NMI_mean   NMI_std  generation_wall_sec_mean  generation_wall_sec_std  zhou_theta_build_wall_sec_mean  zhou_theta_build_wall_sec_std  eigen_decomposition_wall_sec_mean  \
# 0  0.999840  0.000506  0.999491  0.001610                  1.219157                 0.031508                        0.088656                       0.003964                           0.171073
# 1  0.928946  0.007283  0.881908  0.009891                  0.805143                 0.026284                        0.054463                       0.001531                           0.131759
# 2  0.464317  0.018587  0.415698  0.016476                  0.689056                 0.030752                        0.047998                       0.004411                           0.326170
# 3  0.034735  0.007132  0.041416  0.007455                  0.618228                 0.019456                        0.042903                       0.002764                           0.285780
# 4  0.003508  0.001220  0.006258  0.001644                  0.567212                 0.019124                        0.040037                       0.002102                           0.166444
# 5  0.001261  0.000741  0.004506  0.001264                  0.522169                 0.009787                        0.036136                       0.001724                           0.133854
# 6  0.000832  0.000536  0.005155  0.001056                  0.508733                 0.020735                        0.035529                       0.001409                           0.200419
# 7  0.000563  0.000404  0.006177  0.000873                  0.500668                 0.015314                        0.034961                       0.001611                           0.288412
#
#    eigen_decomposition_wall_sec_std  embedding_normalize_wall_sec_mean  embedding_normalize_wall_sec_std  kmeans_wall_sec_mean  kmeans_wall_sec_std  spectral_clustering_wall_sec_mean  spectral_clustering_wall_sec_std  \
# 0                          0.076685                           0.000252                          0.000165              0.159276             0.066817                           0.330608                          0.119010
# 1                          0.016786                           0.000476                          0.000467              0.199427             0.022062                           0.331668                          0.027643
# 2                          0.268558                           0.000577                          0.000400              0.319366             0.030675                           0.646118                          0.275003
# 3                          0.192610                           0.000617                          0.000323              0.644345             0.043845                           0.930749                          0.191843
# 4                          0.086402                           0.000666                          0.000404              0.663974             0.031549                           0.831089                          0.097352
# 5                          0.032137                           0.000366                          0.000196              0.751970             0.043136                           0.886196                          0.069302
# 6                          0.157538                           0.000679                          0.000723              0.810559             0.058572                           1.011665                          0.139741
# 7                          0.183744                           0.001020                          0.000975              0.927854             0.073103                           1.217292                          0.208353
#
#    metric_wall_sec_mean  metric_wall_sec_std  algorithm_total_wall_sec_mean  algorithm_total_wall_sec_std  cpu_time_sec_mean  cpu_time_sec_std  wall_clock_sec_mean  wall_clock_sec_std  peak_traced_memory_mb_mean  \
# 0              0.029148             0.003662                       1.638414                      0.135873           5.407457          0.630093             2.005619            0.141005                   39.983736
# 1              0.026952             0.004302                       1.191269                      0.032126           5.233165          0.206914             1.424176            0.028658                   34.830120
# 2              0.017959             0.001881                       1.383167                      0.294043           7.035912          1.877821             1.569808            0.299715                   33.222691
# 3              0.019656             0.003120                       1.591872                      0.202524           8.543189          1.278933             1.777570            0.212833                   32.520156
# 4              0.016787             0.001488                       1.438333                      0.109334           7.840787          0.639013             1.594807            0.116758                   32.250500
# 5              0.016744             0.001754                       1.444496                      0.079682           8.180653          0.427311             1.583752            0.081318                   32.175994
# 6              0.016203             0.001519                       1.555919                      0.156556           9.016224          0.972463             1.692486            0.152523                   32.343994
# 7              0.017452             0.002130                       1.752915                      0.217895          10.024341          1.421655             1.893323            0.218583                   32.638969
#
#    peak_traced_memory_mb_std  rss_delta_mb_mean  rss_delta_mb_std  rp_draw_omega_sec_mean  rp_draw_omega_sec_std  rp_power_iter_sec_mean  rp_power_iter_sec_std  rp_qr_sec_mean  rp_qr_sec_std  rp_build_core_sec_mean  \
# 0                   0.063661          20.014063         35.103322                0.003357               0.000272                0.068196               0.008629        0.076186       0.066367                0.017533
# 1                   0.026456           2.234375         12.137207                0.003240               0.000122                0.047732               0.001638        0.058637       0.014532                0.015815
# 2                   0.048464          -4.509375         34.715161                0.003510               0.000221                0.042579               0.004696        0.237772       0.233606                0.018864
# 3                   0.039793          -3.557812         25.796669                0.003451               0.000110                0.045406               0.005857        0.196672       0.173218                0.020734
# 4                   0.038200           2.946875          8.576846                0.003542               0.000143                0.038645               0.004295        0.099862       0.076818                0.014968
# 5                   0.032684           2.056250         10.970457                0.003580               0.000150                0.035597               0.002734        0.070929       0.021505                0.017264
# 6                   0.038979           1.634375          3.365439                0.003588               0.000121                0.035680               0.002519        0.131113       0.138058                0.015014
# 7                   0.037362          -2.700000         18.188973                0.003710               0.000263                0.037958               0.004627        0.209952       0.173712                0.020782
#
#    rp_build_core_sec_std  rp_small_eig_sec_mean  rp_small_eig_sec_std  rp_lift_sec_mean  rp_lift_sec_std  top_eigenvalue_max_mean  top_eigenvalue_max_std  top_eigenvalue_min_mean  top_eigenvalue_min_std
# 0               0.003692               0.004622              0.001949          0.000466         0.000252                 0.999994            8.898290e-07                 0.793820                0.001892
# 1               0.003647               0.005150              0.003355          0.000273         0.000036                 0.999979            3.163539e-06                 0.687470                0.002468
# 2               0.018387               0.021230              0.027504          0.000992         0.001551                 0.999955            5.622553e-06                 0.626683                0.001715
# 3               0.005936               0.016632              0.016353          0.001640         0.001546                 0.999926            1.108371e-05                 0.622992                0.001442
# 4               0.006639               0.007258              0.004284          0.001090         0.001027                 0.999909            1.231256e-05                 0.633112                0.001429
# 5               0.008820               0.004932              0.001289          0.000510         0.000455                 0.999878            1.761532e-05                 0.644853                0.000918
# 6               0.004567               0.012606              0.014176          0.000710         0.000906                 0.999838            2.972371e-05                 0.650818                0.001253
# 7               0.009742               0.013522              0.007598          0.001262         0.001363                 0.999855            1.606449e-05                 0.652654                0.001196

# %% [markdown]
# ## 저장된 파일
#
# 실험이 끝나면 아래 경로에 raw 결과, summary 결과, 설정 파일, 요약 그림이 저장된다.

# %%
outputs["paths"]
# Out:
# {'raw': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_raw.csv'),
#  'summary': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_summary.csv'),
#  'config': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_config.json'),
#  'plot': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_summary.png')}
