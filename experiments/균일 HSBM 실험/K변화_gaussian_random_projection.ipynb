# %% [markdown]
# # 균일 HSBM K 변화 - 가우시안 랜덤 프로젝션
#
# 이 노트북은 균일 HSBM의 `K` 변화 실험을 `가우시안 랜덤 프로젝션` 방식으로 실행한다.
#
# 가우시안 랜덤 프로젝션은 `Theta`에 Gaussian test matrix를 곱해 낮은 차원의 부분공간을 만든 뒤, 작은 core matrix의 고유벡터를 원래 공간으로 lift한다.
#
# 하이퍼그래프 생성식은 기존 비랜덤 실험과 동일하게 `p_in = a_in * rho_n / n ** (m - 1)`, `p_out = b_out * rho_n / n ** (m - 1)`를 사용한다.

# %% [markdown]
# ## 실행 설정
#
# 공통 실행 코드는 `uniform_hsbm_randomized.py`에 두었다. 이 노트북은 해당 실행기를 호출하고, raw CSV, summary CSV, 설정 JSON, 요약 그림을 `results/` 아래에 저장한다.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "src" / "common.py").exists():
        PROJECT_ROOT = candidate
        break

EXPERIMENT_DIR = PROJECT_ROOT / "experiments" / "균일 HSBM 실험"
if str(EXPERIMENT_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENT_DIR))

from uniform_hsbm_randomized import resolve_spec, run_named_experiment

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)
SPEC = resolve_spec(sweep='K', method='gaussian_random_projection')
SPEC
# Out:
# SweepSpec(sweep='K', method='gaussian_random_projection', experiment_id='EXP-20260428-001', experiment_slug='uniform_hsbm_K_sweep_gaussian_random_projection', notebook_name='K변화_gaussian_random_projection.ipynb', title_ko='균일 HSBM K 변화 - 가우시안 랜덤 프로젝션', x_col='K', x_values=(2, 3, 4, 5, 6, 8, 10, 12), n=5000, K=None, m=3, a_in=36.0, b_out=4.0, rho_n=8.0, reps=10, seed=20260427, sampling='sparse', max_enumeration=1500000, normalize_embedding_rows=True, eigsh_tol=1e-06, rp_oversampling=160, rp_power_iter=4, random_sampling_p=0.7, kmeans_n_init=20)

# %% [markdown]
# ## 실험 실행
#
# 아래 셀을 실행하면 모든 반복을 수행하고 결과 파일을 저장한다.

# %%
outputs = run_named_experiment(sweep='K', method='gaussian_random_projection', show_progress=True)
summary = outputs["summary"]
summary
# Out:
# | [----------------------------------]    1/  80 (  1.2%) | K=2 rep=01/10 method=Gaussian random projection | elapsed=00:03 eta=05:02
# / [----------------------------------]    2/  80 (  2.5%) | K=2 rep=02/10 method=Gaussian random projection | elapsed=00:07 eta=04:53
# - [#---------------------------------]    3/  80 (  3.8%) | K=2 rep=03/10 method=Gaussian random projection | elapsed=00:11 eta=04:50
# \ [#---------------------------------]    4/  80 (  5.0%) | K=2 rep=04/10 method=Gaussian random projection | elapsed=00:15 eta=04:45
# | [##--------------------------------]    5/  80 (  6.2%) | K=2 rep=05/10 method=Gaussian random projection | elapsed=00:18 eta=04:41
# / [##--------------------------------]    6/  80 (  7.5%) | K=2 rep=06/10 method=Gaussian random projection | elapsed=00:22 eta=04:36
# - [##--------------------------------]    7/  80 (  8.8%) | K=2 rep=07/10 method=Gaussian random projection | elapsed=00:26 eta=04:31
# \ [###-------------------------------]    8/  80 ( 10.0%) | K=2 rep=08/10 method=Gaussian random projection | elapsed=00:29 eta=04:27
# | [###-------------------------------]    9/  80 ( 11.2%) | K=2 rep=09/10 method=Gaussian random projection | elapsed=00:33 eta=04:22
# / [####------------------------------]   10/  80 ( 12.5%) | K=2 rep=10/10 method=Gaussian random projection | elapsed=00:37 eta=04:19
# - [####------------------------------]   11/  80 ( 13.8%) | K=3 rep=01/10 method=Gaussian random projection | elapsed=00:39 eta=04:07
# \ [#####-----------------------------]   12/  80 ( 15.0%) | K=3 rep=02/10 method=Gaussian random projection | elapsed=00:42 eta=03:58
# | [#####-----------------------------]   13/  80 ( 16.2%) | K=3 rep=03/10 method=Gaussian random projection | elapsed=00:44 eta=03:49
# / [#####-----------------------------]   14/  80 ( 17.5%) | K=3 rep=04/10 method=Gaussian random projection | elapsed=00:47 eta=03:42
# - [######----------------------------]   15/  80 ( 18.8%) | K=3 rep=05/10 method=Gaussian random projection | elapsed=00:49 eta=03:34
# \ [######----------------------------]   16/  80 ( 20.0%) | K=3 rep=06/10 method=Gaussian random projection | elapsed=00:52 eta=03:28
# | [#######---------------------------]   17/  80 ( 21.2%) | K=3 rep=07/10 method=Gaussian random projection | elapsed=00:54 eta=03:22
# / [#######---------------------------]   18/  80 ( 22.5%) | K=3 rep=08/10 method=Gaussian random projection | elapsed=00:57 eta=03:16
# - [########--------------------------]   19/  80 ( 23.8%) | K=3 rep=09/10 method=Gaussian random projection | elapsed=00:59 eta=03:11
# \ [########--------------------------]   20/  80 ( 25.0%) | K=3 rep=10/10 method=Gaussian random projection | elapsed=01:02 eta=03:06
# | [########--------------------------]   21/  80 ( 26.2%) | K=4 rep=01/10 method=Gaussian random projection | elapsed=01:04 eta=03:00
# / [#########-------------------------]   22/  80 ( 27.5%) | K=4 rep=02/10 method=Gaussian random projection | elapsed=01:06 eta=02:55
# - [#########-------------------------]   23/  80 ( 28.7%) | K=4 rep=03/10 method=Gaussian random projection | elapsed=01:08 eta=02:50
# \ [##########------------------------]   24/  80 ( 30.0%) | K=4 rep=04/10 method=Gaussian random projection | elapsed=01:10 eta=02:45
# | [##########------------------------]   25/  80 ( 31.2%) | K=4 rep=05/10 method=Gaussian random projection | elapsed=01:13 eta=02:40
# / [###########-----------------------]   26/  80 ( 32.5%) | K=4 rep=06/10 method=Gaussian random projection | elapsed=01:15 eta=02:36
# - [###########-----------------------]   27/  80 ( 33.8%) | K=4 rep=07/10 method=Gaussian random projection | elapsed=01:17 eta=02:32
# \ [###########-----------------------]   28/  80 ( 35.0%) | K=4 rep=08/10 method=Gaussian random projection | elapsed=01:19 eta=02:28
# | [############----------------------]   29/  80 ( 36.2%) | K=4 rep=09/10 method=Gaussian random projection | elapsed=01:22 eta=02:24
# / [############----------------------]   30/  80 ( 37.5%) | K=4 rep=10/10 method=Gaussian random projection | elapsed=01:24 eta=02:20
# - [#############---------------------]   31/  80 ( 38.8%) | K=5 rep=01/10 method=Gaussian random projection | elapsed=01:26 eta=02:16
# \ [#############---------------------]   32/  80 ( 40.0%) | K=5 rep=02/10 method=Gaussian random projection | elapsed=01:28 eta=02:12
# | [##############--------------------]   33/  80 ( 41.2%) | K=5 rep=03/10 method=Gaussian random projection | elapsed=01:30 eta=02:08
# / [##############--------------------]   34/  80 ( 42.5%) | K=5 rep=04/10 method=Gaussian random projection | elapsed=01:32 eta=02:05
# - [##############--------------------]   35/  80 ( 43.8%) | K=5 rep=05/10 method=Gaussian random projection | elapsed=01:34 eta=02:01
# \ [###############-------------------]   36/  80 ( 45.0%) | K=5 rep=06/10 method=Gaussian random projection | elapsed=01:36 eta=01:58
# | [###############-------------------]   37/  80 ( 46.2%) | K=5 rep=07/10 method=Gaussian random projection | elapsed=01:38 eta=01:54
# / [################------------------]   38/  80 ( 47.5%) | K=5 rep=08/10 method=Gaussian random projection | elapsed=01:40 eta=01:51
# - [################------------------]   39/  80 ( 48.8%) | K=5 rep=09/10 method=Gaussian random projection | elapsed=01:42 eta=01:47
# \ [#################-----------------]   40/  80 ( 50.0%) | K=5 rep=10/10 method=Gaussian random projection | elapsed=01:44 eta=01:44
# | [#################-----------------]   41/  80 ( 51.2%) | K=6 rep=01/10 method=Gaussian random projection | elapsed=01:47 eta=01:41
# / [#################-----------------]   42/  80 ( 52.5%) | K=6 rep=02/10 method=Gaussian random projection | elapsed=01:49 eta=01:38
# - [##################----------------]   43/  80 ( 53.8%) | K=6 rep=03/10 method=Gaussian random projection | elapsed=01:51 eta=01:36
# \ [##################----------------]   44/  80 ( 55.0%) | K=6 rep=04/10 method=Gaussian random projection | elapsed=01:53 eta=01:33
# | [###################---------------]   45/  80 ( 56.2%) | K=6 rep=05/10 method=Gaussian random projection | elapsed=01:56 eta=01:30
# / [###################---------------]   46/  80 ( 57.5%) | K=6 rep=06/10 method=Gaussian random projection | elapsed=01:58 eta=01:27
# - [###################---------------]   47/  80 ( 58.8%) | K=6 rep=07/10 method=Gaussian random projection | elapsed=02:01 eta=01:25
# \ [####################--------------]   48/  80 ( 60.0%) | K=6 rep=08/10 method=Gaussian random projection | elapsed=02:03 eta=01:22
# | [####################--------------]   49/  80 ( 61.3%) | K=6 rep=09/10 method=Gaussian random projection | elapsed=02:06 eta=01:19
# / [#####################-------------]   50/  80 ( 62.5%) | K=6 rep=10/10 method=Gaussian random projection | elapsed=02:08 eta=01:17
# - [#####################-------------]   51/  80 ( 63.7%) | K=8 rep=01/10 method=Gaussian random projection | elapsed=02:11 eta=01:14
# \ [######################------------]   52/  80 ( 65.0%) | K=8 rep=02/10 method=Gaussian random projection | elapsed=02:13 eta=01:11
# | [######################------------]   53/  80 ( 66.2%) | K=8 rep=03/10 method=Gaussian random projection | elapsed=02:15 eta=01:09
# / [######################------------]   54/  80 ( 67.5%) | K=8 rep=04/10 method=Gaussian random projection | elapsed=02:17 eta=01:06
# - [#######################-----------]   55/  80 ( 68.8%) | K=8 rep=05/10 method=Gaussian random projection | elapsed=02:20 eta=01:03
# \ [#######################-----------]   56/  80 ( 70.0%) | K=8 rep=06/10 method=Gaussian random projection | elapsed=02:22 eta=01:00
# | [########################----------]   57/  80 ( 71.2%) | K=8 rep=07/10 method=Gaussian random projection | elapsed=02:24 eta=00:58
# / [########################----------]   58/  80 ( 72.5%) | K=8 rep=08/10 method=Gaussian random projection | elapsed=02:26 eta=00:55
# - [#########################---------]   59/  80 ( 73.8%) | K=8 rep=09/10 method=Gaussian random projection | elapsed=02:29 eta=00:53
# \ [#########################---------]   60/  80 ( 75.0%) | K=8 rep=10/10 method=Gaussian random projection | elapsed=02:31 eta=00:50
# | [#########################---------]   61/  80 ( 76.2%) | K=10 rep=01/10 method=Gaussian random projection | elapsed=02:33 eta=00:47
# / [##########################--------]   62/  80 ( 77.5%) | K=10 rep=02/10 method=Gaussian random projection | elapsed=02:35 eta=00:45
# - [##########################--------]   63/  80 ( 78.8%) | K=10 rep=03/10 method=Gaussian random projection | elapsed=02:38 eta=00:42
# \ [###########################-------]   64/  80 ( 80.0%) | K=10 rep=04/10 method=Gaussian random projection | elapsed=02:40 eta=00:40
# | [###########################-------]   65/  80 ( 81.2%) | K=10 rep=05/10 method=Gaussian random projection | elapsed=02:43 eta=00:37
# / [############################------]   66/  80 ( 82.5%) | K=10 rep=06/10 method=Gaussian random projection | elapsed=02:45 eta=00:35
# - [############################------]   67/  80 ( 83.8%) | K=10 rep=07/10 method=Gaussian random projection | elapsed=02:47 eta=00:32
# \ [############################------]   68/  80 ( 85.0%) | K=10 rep=08/10 method=Gaussian random projection | elapsed=02:50 eta=00:30
# | [#############################-----]   69/  80 ( 86.2%) | K=10 rep=09/10 method=Gaussian random projection | elapsed=02:52 eta=00:27
# / [#############################-----]   70/  80 ( 87.5%) | K=10 rep=10/10 method=Gaussian random projection | elapsed=02:54 eta=00:24
# - [##############################----]   71/  80 ( 88.8%) | K=12 rep=01/10 method=Gaussian random projection | elapsed=02:57 eta=00:22
# \ [##############################----]   72/  80 ( 90.0%) | K=12 rep=02/10 method=Gaussian random projection | elapsed=02:59 eta=00:19
# | [###############################---]   73/  80 ( 91.2%) | K=12 rep=03/10 method=Gaussian random projection | elapsed=03:02 eta=00:17
# / [###############################---]   74/  80 ( 92.5%) | K=12 rep=04/10 method=Gaussian random projection | elapsed=03:04 eta=00:14
# - [###############################---]   75/  80 ( 93.8%) | K=12 rep=05/10 method=Gaussian random projection | elapsed=03:07 eta=00:12
# \ [################################--]   76/  80 ( 95.0%) | K=12 rep=06/10 method=Gaussian random projection | elapsed=03:09 eta=00:09
# | [################################--]   77/  80 ( 96.2%) | K=12 rep=07/10 method=Gaussian random projection | elapsed=03:12 eta=00:07
# / [#################################-]   78/  80 ( 97.5%) | K=12 rep=08/10 method=Gaussian random projection | elapsed=03:14 eta=00:04
# - [#################################-]   79/  80 ( 98.8%) | K=12 rep=09/10 method=Gaussian random projection | elapsed=03:16 eta=00:02
# \ [##################################]   80/  80 (100.0%) | K=12 rep=10/10 method=Gaussian random projection | elapsed=03:19 eta=00:00
#     K                      method  reps  num_hyperedges_total_mean  num_hyperedges_total_std  hypergraph_degree_mean_mean  hypergraph_degree_mean_std  hypergraph_degree_max_mean  hypergraph_degree_max_std  \
# 0   2  Gaussian random projection    10                    79859.4                272.844359                     47.91564                    0.163707                        75.8                   3.047768
# 1   3  Gaussian random projection    10                    50320.3                248.887324                     30.19218                    0.149332                        51.1                   1.100505
# 2   4  Gaussian random projection    10                    40057.4                176.652326                     24.03444                    0.105991                        44.6                   2.270585
# 3   5  Gaussian random projection    10                    35211.9                165.897860                     21.12714                    0.099539                        39.7                   2.668749
# 4   6  Gaussian random projection    10                    32484.7                154.071448                     19.49082                    0.092443                        38.5                   1.581139
# 5   8  Gaussian random projection    10                    29963.4                109.806092                     17.97804                    0.065884                        35.5                   1.509231
# 6  10  Gaussian random projection    10                    28804.6                171.266654                     17.28276                    0.102760                        35.0                   1.414214
# 7  12  Gaussian random projection    10                    28086.9                189.128087                     16.85214                    0.113477                        33.8                   1.932184
#
#    expected_degree_mean_mean  expected_degree_mean_std  candidate_within_fraction_mean  candidate_within_fraction_std  isolated_fraction_mean  isolated_fraction_std  misclassification_mean  misclassification_std  \
# 0                  47.952012                       0.0                        0.249850                            0.0                     0.0                    0.0                 0.00000               0.000000
# 1                  30.187037                       0.0                        0.110978                            0.0                     0.0                    0.0                 0.00084               0.000409
# 2                  23.971212                       0.0                        0.062388                            0.0                     0.0                    0.0                 0.05422               0.005316
# 3                  21.095052                       0.0                        0.039904                            0.0                     0.0                    0.0                 0.29356               0.015786
# 4                  19.533170                       0.0                        0.027694                            0.0                     0.0                    0.0                 0.71340               0.021345
# 5                  17.980812                       0.0                        0.015559                            0.0                     0.0                    0.0                 0.84332               0.004730
# 6                  17.262732                       0.0                        0.009946                            0.0                     0.0                    0.0                 0.87616               0.002536
# 7                  16.872904                       0.0                        0.006899                            0.0                     0.0                    0.0                 0.89266               0.002844
#
#    ARI_mean   ARI_std  NMI_mean   NMI_std  generation_wall_sec_mean  generation_wall_sec_std  zhou_theta_build_wall_sec_mean  zhou_theta_build_wall_sec_std  eigen_decomposition_wall_sec_mean  \
# 0  1.000000  0.000000  1.000000  0.000000                  2.426260                 0.025709                        0.175232                       0.005744                           0.230262
# 1  0.997481  0.001225  0.993844  0.002815                  1.577259                 0.017257                        0.113032                       0.003865                           0.178090
# 2  0.860681  0.013150  0.806230  0.015175                  1.335318                 0.033926                        0.089814                       0.003180                           0.155338
# 3  0.401769  0.025018  0.374043  0.022275                  1.144953                 0.018718                        0.074629                       0.001715                           0.152045
# 4  0.036655  0.006718  0.048052  0.007520                  1.143672                 0.066243                        0.076270                       0.007424                           0.167167
# 5  0.002753  0.000776  0.006918  0.001223                  1.011488                 0.022694                        0.066439                       0.002813                           0.145011
# 6  0.001090  0.000511  0.005670  0.000989                  0.988340                 0.024440                        0.065694                       0.003237                           0.144180
# 7  0.000586  0.000311  0.006141  0.000659                  0.968753                 0.030049                        0.065008                       0.004728                           0.156039
#
#    eigen_decomposition_wall_sec_std  embedding_normalize_wall_sec_mean  embedding_normalize_wall_sec_std  kmeans_wall_sec_mean  kmeans_wall_sec_std  spectral_clustering_wall_sec_mean  spectral_clustering_wall_sec_std  \
# 0                          0.030083                           0.000303                          0.000206              0.142912             0.035252                           0.373484                          0.052963
# 1                          0.013128                           0.000531                          0.000390              0.183623             0.041363                           0.362249                          0.038870
# 2                          0.017026                           0.000500                          0.000662              0.264896             0.034848                           0.420741                          0.045010
# 3                          0.021358                           0.000366                          0.000323              0.335989             0.028088                           0.488405                          0.035907
# 4                          0.038615                           0.000464                          0.000325              0.682218             0.038548                           0.849855                          0.061974
# 5                          0.019630                           0.000454                          0.000274              0.756064             0.042457                           0.901537                          0.053136
# 6                          0.017346                           0.000296                          0.000113              0.863602             0.040934                           1.008082                          0.037610
# 7                          0.049879                           0.000654                          0.000746              0.945717             0.075743                           1.102415                          0.106658
#
#    metric_wall_sec_mean  metric_wall_sec_std  algorithm_total_wall_sec_mean  algorithm_total_wall_sec_std  cpu_time_sec_mean  cpu_time_sec_std  wall_clock_sec_mean  wall_clock_sec_std  peak_traced_memory_mb_mean  \
# 0              0.027536             0.006895                       2.974970                      0.071298           7.059344          0.297052             3.660066            0.074880                   54.239654
# 1              0.023579             0.004207                       2.052534                      0.031740           6.212818          0.348610             2.476474            0.023723                   43.887534
# 2              0.019911             0.003964                       1.845865                      0.068402           6.224690          0.460144             2.185102            0.082993                   40.410629
# 3              0.016385             0.000627                       1.707982                      0.032431           6.823360          0.243876             1.990707            0.035101                   38.870531
# 4              0.017575             0.002050                       2.069792                      0.076175           8.854102          0.317957             2.354878            0.086902                   38.088632
# 5              0.015995             0.001199                       1.979456                      0.057791           9.199081          0.301793             2.226548            0.065366                   37.574383
# 6              0.017608             0.002086                       2.062111                      0.054422           9.711097          0.383177             2.311570            0.075138                   37.549343
# 7              0.016651             0.001646                       2.136172                      0.123207          10.050551          0.830276             2.382397            0.137953                   37.683070
#
#    peak_traced_memory_mb_std  rss_delta_mb_mean  rss_delta_mb_std  rp_draw_omega_sec_mean  rp_draw_omega_sec_std  rp_power_iter_sec_mean  rp_power_iter_sec_std  rp_qr_sec_mean  rp_qr_sec_std  rp_build_core_sec_mean  \
# 0                   0.096699          29.751562         40.081537                0.003358               0.000220                0.121989               0.005450        0.060789       0.023944                0.038095
# 1                   0.088657           2.957813          5.200896                0.003338               0.000151                0.087998               0.003845        0.057087       0.010848                0.023182
# 2                   0.064219         -16.435938         47.830193                0.003356               0.000150                0.068348               0.005207        0.056051       0.007748                0.018486
# 3                   0.059464           5.317188          6.237357                0.003315               0.000113                0.064235               0.002482        0.055673       0.009668                0.021587
# 4                   0.055134         -11.145312         50.903907                0.003586               0.000378                0.061734               0.006269        0.076578       0.035375                0.019824
# 5                   0.039930           9.767188         16.879357                0.003403               0.000073                0.052981               0.004145        0.059989       0.006696                0.021141
# 6                   0.061105          -4.606250         55.202133                0.003464               0.000150                0.052863               0.003039        0.061625       0.010366                0.018476
# 7                   0.067472          -4.181250         58.877931                0.003526               0.000182                0.053559               0.005459        0.074392       0.038698                0.016866
#
#    rp_build_core_sec_std  rp_small_eig_sec_mean  rp_small_eig_sec_std  rp_lift_sec_mean  rp_lift_sec_std  top_eigenvalue_max_mean  top_eigenvalue_max_std  top_eigenvalue_min_mean  top_eigenvalue_min_std
# 0               0.010920               0.004462              0.001639          0.000588         0.000667                 0.999999            1.378951e-07                 0.785671                0.000998
# 1               0.005892               0.004136              0.001178          0.000868         0.001046                 0.999997            3.791483e-07                 0.667528                0.001816
# 2               0.005163               0.007495              0.008662          0.000803         0.000958                 0.999995            5.782576e-07                 0.587280                0.002533
# 3               0.010848               0.006035              0.008154          0.000326         0.000204                 0.999992            8.128958e-07                 0.543172                0.002566
# 4               0.005971               0.004302              0.001770          0.000303         0.000061                 0.999990            1.241427e-06                 0.539957                0.000757
# 5               0.008631               0.006043              0.005559          0.000622         0.000797                 0.999988            2.021296e-06                 0.547202                0.000526
# 6               0.005684               0.006332              0.002926          0.000527         0.000318                 0.999985            1.975881e-06                 0.550924                0.000766
# 7               0.004536               0.005530              0.003912          0.000950         0.001561                 0.999985            1.822030e-06                 0.552949                0.000773

# %% [markdown]
# ## 저장된 파일
#
# 실험이 끝나면 아래 경로에 raw 결과, summary 결과, 설정 파일, 요약 그림이 저장된다.

# %%
outputs["paths"]
# Out:
# {'raw': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_raw.csv'),
#  'summary': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_summary.csv'),
#  'config': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_config.json'),
#  'plot': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection/EXP-20260428-001_uniform_hsbm_K_sweep_gaussian_random_projection_summary.png')}
