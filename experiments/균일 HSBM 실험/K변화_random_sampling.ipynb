# %% [markdown]
# # 균일 HSBM K 변화 - 랜덤 샘플링
#
# 이 노트북은 균일 HSBM의 `K` 변화 실험을 `랜덤 샘플링` 방식으로 실행한다.
#
# 랜덤 샘플링은 `Theta`의 sparse nonzero entry를 확률 `p=0.7`로 뽑고 `1/p`로 rescale한 sampled operator에 `eigsh`를 적용한다.
#
# 하이퍼그래프 생성식은 기존 비랜덤 실험과 동일하게 `p_in = a_in * rho_n / n ** (m - 1)`, `p_out = b_out * rho_n / n ** (m - 1)`를 사용한다.

# %% [markdown]
# ## 실행 설정
#
# 공통 실행 코드는 `uniform_hsbm_randomized.py`에 두었다. 이 노트북은 해당 실행기를 호출하고, raw CSV, summary CSV, 설정 JSON, 요약 그림을 `results/` 아래에 저장한다.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "src" / "common.py").exists():
        PROJECT_ROOT = candidate
        break

EXPERIMENT_DIR = PROJECT_ROOT / "experiments" / "균일 HSBM 실험"
if str(EXPERIMENT_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENT_DIR))

from uniform_hsbm_randomized import resolve_spec, run_named_experiment

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)
SPEC = resolve_spec(sweep='K', method='random_sampling')
SPEC
# Out:
# SweepSpec(sweep='K', method='random_sampling', experiment_id='EXP-20260428-002', experiment_slug='uniform_hsbm_K_sweep_random_sampling', notebook_name='K변화_random_sampling.ipynb', title_ko='균일 HSBM K 변화 - 랜덤 샘플링', x_col='K', x_values=(2, 3, 4, 5, 6, 8, 10, 12), n=5000, K=None, m=3, a_in=36.0, b_out=4.0, rho_n=8.0, reps=10, seed=20260427, sampling='sparse', max_enumeration=1500000, normalize_embedding_rows=True, eigsh_tol=1e-06, rp_oversampling=10, rp_power_iter=2, random_sampling_p=0.7, kmeans_n_init=20)

# %% [markdown]
# ## 실험 실행
#
# 아래 셀을 실행하면 모든 반복을 수행하고 결과 파일을 저장한다.

# %%
outputs = run_named_experiment(sweep='K', method='random_sampling', show_progress=True)
summary = outputs["summary"]
summary
# Out:
# | [----------------------------------]    1/  80 (  1.2%) | K=2 rep=01/10 method=Random sampling   | elapsed=00:03 eta=04:39
# / [----------------------------------]    2/  80 (  2.5%) | K=2 rep=02/10 method=Random sampling   | elapsed=00:06 eta=04:28
# - [#---------------------------------]    3/  80 (  3.8%) | K=2 rep=03/10 method=Random sampling   | elapsed=00:10 eta=04:23
# \ [#---------------------------------]    4/  80 (  5.0%) | K=2 rep=04/10 method=Random sampling   | elapsed=00:13 eta=04:18
# | [##--------------------------------]    5/  80 (  6.2%) | K=2 rep=05/10 method=Random sampling   | elapsed=00:16 eta=04:14
# / [##--------------------------------]    6/  80 (  7.5%) | K=2 rep=06/10 method=Random sampling   | elapsed=00:20 eta=04:11
# - [##--------------------------------]    7/  80 (  8.8%) | K=2 rep=07/10 method=Random sampling   | elapsed=00:23 eta=04:07
# \ [###-------------------------------]    8/  80 ( 10.0%) | K=2 rep=08/10 method=Random sampling   | elapsed=00:27 eta=04:03
# | [###-------------------------------]    9/  80 ( 11.2%) | K=2 rep=09/10 method=Random sampling   | elapsed=00:30 eta=04:00
# / [####------------------------------]   10/  80 ( 12.5%) | K=2 rep=10/10 method=Random sampling   | elapsed=00:33 eta=03:56
# - [####------------------------------]   11/  80 ( 13.8%) | K=3 rep=01/10 method=Random sampling   | elapsed=00:36 eta=03:45
# \ [#####-----------------------------]   12/  80 ( 15.0%) | K=3 rep=02/10 method=Random sampling   | elapsed=00:38 eta=03:36
# | [#####-----------------------------]   13/  80 ( 16.2%) | K=3 rep=03/10 method=Random sampling   | elapsed=00:40 eta=03:28
# / [#####-----------------------------]   14/  80 ( 17.5%) | K=3 rep=04/10 method=Random sampling   | elapsed=00:42 eta=03:21
# - [######----------------------------]   15/  80 ( 18.8%) | K=3 rep=05/10 method=Random sampling   | elapsed=00:45 eta=03:15
# \ [######----------------------------]   16/  80 ( 20.0%) | K=3 rep=06/10 method=Random sampling   | elapsed=00:47 eta=03:10
# | [#######---------------------------]   17/  80 ( 21.2%) | K=3 rep=07/10 method=Random sampling   | elapsed=00:49 eta=03:04
# / [#######---------------------------]   18/  80 ( 22.5%) | K=3 rep=08/10 method=Random sampling   | elapsed=00:52 eta=02:59
# - [########--------------------------]   19/  80 ( 23.8%) | K=3 rep=09/10 method=Random sampling   | elapsed=00:54 eta=02:54
# \ [########--------------------------]   20/  80 ( 25.0%) | K=3 rep=10/10 method=Random sampling   | elapsed=00:56 eta=02:49
# | [########--------------------------]   21/  80 ( 26.2%) | K=4 rep=01/10 method=Random sampling   | elapsed=00:58 eta=02:44
# / [#########-------------------------]   22/  80 ( 27.5%) | K=4 rep=02/10 method=Random sampling   | elapsed=01:00 eta=02:39
# - [#########-------------------------]   23/  80 ( 28.7%) | K=4 rep=03/10 method=Random sampling   | elapsed=01:02 eta=02:34
# \ [##########------------------------]   24/  80 ( 30.0%) | K=4 rep=04/10 method=Random sampling   | elapsed=01:04 eta=02:29
# | [##########------------------------]   25/  80 ( 31.2%) | K=4 rep=05/10 method=Random sampling   | elapsed=01:06 eta=02:25
# / [###########-----------------------]   26/  80 ( 32.5%) | K=4 rep=06/10 method=Random sampling   | elapsed=01:07 eta=02:21
# - [###########-----------------------]   27/  80 ( 33.8%) | K=4 rep=07/10 method=Random sampling   | elapsed=01:09 eta=02:17
# \ [###########-----------------------]   28/  80 ( 35.0%) | K=4 rep=08/10 method=Random sampling   | elapsed=01:11 eta=02:13
# | [############----------------------]   29/  80 ( 36.2%) | K=4 rep=09/10 method=Random sampling   | elapsed=01:13 eta=02:09
# / [############----------------------]   30/  80 ( 37.5%) | K=4 rep=10/10 method=Random sampling   | elapsed=01:15 eta=02:05
# - [#############---------------------]   31/  80 ( 38.8%) | K=5 rep=01/10 method=Random sampling   | elapsed=01:17 eta=02:02
# \ [#############---------------------]   32/  80 ( 40.0%) | K=5 rep=02/10 method=Random sampling   | elapsed=01:19 eta=01:59
# | [##############--------------------]   33/  80 ( 41.2%) | K=5 rep=03/10 method=Random sampling   | elapsed=01:21 eta=01:55
# / [##############--------------------]   34/  80 ( 42.5%) | K=5 rep=04/10 method=Random sampling   | elapsed=01:23 eta=01:52
# - [##############--------------------]   35/  80 ( 43.8%) | K=5 rep=05/10 method=Random sampling   | elapsed=01:25 eta=01:49
# \ [###############-------------------]   36/  80 ( 45.0%) | K=5 rep=06/10 method=Random sampling   | elapsed=01:27 eta=01:46
# | [###############-------------------]   37/  80 ( 46.2%) | K=5 rep=07/10 method=Random sampling   | elapsed=01:29 eta=01:43
# / [################------------------]   38/  80 ( 47.5%) | K=5 rep=08/10 method=Random sampling   | elapsed=01:31 eta=01:40
# - [################------------------]   39/  80 ( 48.8%) | K=5 rep=09/10 method=Random sampling   | elapsed=01:33 eta=01:37
# \ [#################-----------------]   40/  80 ( 50.0%) | K=5 rep=10/10 method=Random sampling   | elapsed=01:35 eta=01:35
# | [#################-----------------]   41/  80 ( 51.2%) | K=6 rep=01/10 method=Random sampling   | elapsed=01:37 eta=01:32
# / [#################-----------------]   42/  80 ( 52.5%) | K=6 rep=02/10 method=Random sampling   | elapsed=01:39 eta=01:29
# - [##################----------------]   43/  80 ( 53.8%) | K=6 rep=03/10 method=Random sampling   | elapsed=01:41 eta=01:27
# \ [##################----------------]   44/  80 ( 55.0%) | K=6 rep=04/10 method=Random sampling   | elapsed=01:43 eta=01:24
# | [###################---------------]   45/  80 ( 56.2%) | K=6 rep=05/10 method=Random sampling   | elapsed=01:45 eta=01:21
# / [###################---------------]   46/  80 ( 57.5%) | K=6 rep=06/10 method=Random sampling   | elapsed=01:47 eta=01:19
# - [###################---------------]   47/  80 ( 58.8%) | K=6 rep=07/10 method=Random sampling   | elapsed=01:49 eta=01:16
# \ [####################--------------]   48/  80 ( 60.0%) | K=6 rep=08/10 method=Random sampling   | elapsed=01:52 eta=01:14
# | [####################--------------]   49/  80 ( 61.3%) | K=6 rep=09/10 method=Random sampling   | elapsed=01:54 eta=01:12
# / [#####################-------------]   50/  80 ( 62.5%) | K=6 rep=10/10 method=Random sampling   | elapsed=01:57 eta=01:10
# - [#####################-------------]   51/  80 ( 63.7%) | K=8 rep=01/10 method=Random sampling   | elapsed=01:59 eta=01:07
# \ [######################------------]   52/  80 ( 65.0%) | K=8 rep=02/10 method=Random sampling   | elapsed=02:01 eta=01:05
# | [######################------------]   53/  80 ( 66.2%) | K=8 rep=03/10 method=Random sampling   | elapsed=02:03 eta=01:02
# / [######################------------]   54/  80 ( 67.5%) | K=8 rep=04/10 method=Random sampling   | elapsed=02:05 eta=01:00
# - [#######################-----------]   55/  80 ( 68.8%) | K=8 rep=05/10 method=Random sampling   | elapsed=02:07 eta=00:57
# \ [#######################-----------]   56/  80 ( 70.0%) | K=8 rep=06/10 method=Random sampling   | elapsed=02:09 eta=00:55
# | [########################----------]   57/  80 ( 71.2%) | K=8 rep=07/10 method=Random sampling   | elapsed=02:11 eta=00:53
# / [########################----------]   58/  80 ( 72.5%) | K=8 rep=08/10 method=Random sampling   | elapsed=02:13 eta=00:50
# - [#########################---------]   59/  80 ( 73.8%) | K=8 rep=09/10 method=Random sampling   | elapsed=02:15 eta=00:48
# \ [#########################---------]   60/  80 ( 75.0%) | K=8 rep=10/10 method=Random sampling   | elapsed=02:17 eta=00:45
# | [#########################---------]   61/  80 ( 76.2%) | K=10 rep=01/10 method=Random sampling   | elapsed=02:19 eta=00:43
# / [##########################--------]   62/  80 ( 77.5%) | K=10 rep=02/10 method=Random sampling   | elapsed=02:22 eta=00:41
# - [##########################--------]   63/  80 ( 78.8%) | K=10 rep=03/10 method=Random sampling   | elapsed=02:24 eta=00:38
# \ [###########################-------]   64/  80 ( 80.0%) | K=10 rep=04/10 method=Random sampling   | elapsed=02:26 eta=00:36
# | [###########################-------]   65/  80 ( 81.2%) | K=10 rep=05/10 method=Random sampling   | elapsed=02:28 eta=00:34
# / [############################------]   66/  80 ( 82.5%) | K=10 rep=06/10 method=Random sampling   | elapsed=02:30 eta=00:31
# - [############################------]   67/  80 ( 83.8%) | K=10 rep=07/10 method=Random sampling   | elapsed=02:32 eta=00:29
# \ [############################------]   68/  80 ( 85.0%) | K=10 rep=08/10 method=Random sampling   | elapsed=02:34 eta=00:27
# | [#############################-----]   69/  80 ( 86.2%) | K=10 rep=09/10 method=Random sampling   | elapsed=02:37 eta=00:25
# / [#############################-----]   70/  80 ( 87.5%) | K=10 rep=10/10 method=Random sampling   | elapsed=02:39 eta=00:22
# - [##############################----]   71/  80 ( 88.8%) | K=12 rep=01/10 method=Random sampling   | elapsed=02:41 eta=00:20
# \ [##############################----]   72/  80 ( 90.0%) | K=12 rep=02/10 method=Random sampling   | elapsed=02:43 eta=00:18
# | [###############################---]   73/  80 ( 91.2%) | K=12 rep=03/10 method=Random sampling   | elapsed=02:45 eta=00:15
# / [###############################---]   74/  80 ( 92.5%) | K=12 rep=04/10 method=Random sampling   | elapsed=02:48 eta=00:13
# - [###############################---]   75/  80 ( 93.8%) | K=12 rep=05/10 method=Random sampling   | elapsed=02:50 eta=00:11
# \ [################################--]   76/  80 ( 95.0%) | K=12 rep=06/10 method=Random sampling   | elapsed=02:52 eta=00:09
# | [################################--]   77/  80 ( 96.2%) | K=12 rep=07/10 method=Random sampling   | elapsed=02:54 eta=00:06
# / [#################################-]   78/  80 ( 97.5%) | K=12 rep=08/10 method=Random sampling   | elapsed=02:56 eta=00:04
# - [#################################-]   79/  80 ( 98.8%) | K=12 rep=09/10 method=Random sampling   | elapsed=02:59 eta=00:02
# \ [##################################]   80/  80 (100.0%) | K=12 rep=10/10 method=Random sampling   | elapsed=03:01 eta=00:00
#     K           method  reps  num_hyperedges_total_mean  num_hyperedges_total_std  hypergraph_degree_mean_mean  hypergraph_degree_mean_std  hypergraph_degree_max_mean  hypergraph_degree_max_std  \
# 0   2  Random sampling    10                    79859.4                272.844359                     47.91564                    0.163707                        75.8                   3.047768
# 1   3  Random sampling    10                    50320.3                248.887324                     30.19218                    0.149332                        51.1                   1.100505
# 2   4  Random sampling    10                    40057.4                176.652326                     24.03444                    0.105991                        44.6                   2.270585
# 3   5  Random sampling    10                    35211.9                165.897860                     21.12714                    0.099539                        39.7                   2.668749
# 4   6  Random sampling    10                    32484.7                154.071448                     19.49082                    0.092443                        38.5                   1.581139
# 5   8  Random sampling    10                    29963.4                109.806092                     17.97804                    0.065884                        35.5                   1.509231
# 6  10  Random sampling    10                    28804.6                171.266654                     17.28276                    0.102760                        35.0                   1.414214
# 7  12  Random sampling    10                    28086.9                189.128087                     16.85214                    0.113477                        33.8                   1.932184
#
#    expected_degree_mean_mean  expected_degree_mean_std  candidate_within_fraction_mean  candidate_within_fraction_std  isolated_fraction_mean  isolated_fraction_std  misclassification_mean  misclassification_std  \
# 0                  47.952012                       0.0                        0.249850                            0.0                     0.0                    0.0                 0.00000               0.000000
# 1                  30.187037                       0.0                        0.110978                            0.0                     0.0                    0.0                 0.00522               0.000851
# 2                  23.971212                       0.0                        0.062388                            0.0                     0.0                    0.0                 0.09360               0.006736
# 3                  21.095052                       0.0                        0.039904                            0.0                     0.0                    0.0                 0.41914               0.033761
# 4                  19.533170                       0.0                        0.027694                            0.0                     0.0                    0.0                 0.77344               0.011677
# 5                  17.980812                       0.0                        0.015559                            0.0                     0.0                    0.0                 0.84934               0.003265
# 6                  17.262732                       0.0                        0.009946                            0.0                     0.0                    0.0                 0.87624               0.002057
# 7                  16.872904                       0.0                        0.006899                            0.0                     0.0                    0.0                 0.89250               0.001912
#
#    ARI_mean   ARI_std  NMI_mean   NMI_std  generation_wall_sec_mean  generation_wall_sec_std  zhou_theta_build_wall_sec_mean  zhou_theta_build_wall_sec_std  eigen_decomposition_wall_sec_mean  \
# 0  1.000000  0.000000  1.000000  0.000000                  2.426920                 0.039184                        0.174301                       0.004822                           0.016774
# 1  0.984399  0.002532  0.967461  0.004544                  1.603399                 0.055848                        0.110459                       0.004316                           0.014882
# 2  0.765973  0.015736  0.702753  0.016759                  1.287054                 0.021835                        0.086633                       0.002177                           0.018547
# 3  0.233375  0.036922  0.226491  0.032246                  1.165215                 0.029357                        0.081389                       0.013057                           0.040401
# 4  0.010989  0.002523  0.016388  0.003234                  1.198362                 0.153729                        0.086598                       0.042586                           0.076009
# 5  0.001680  0.000576  0.005171  0.000950                  1.039776                 0.044758                        0.072501                       0.012477                           0.069369
# 6  0.000806  0.000346  0.005065  0.000649                  0.979222                 0.026506                        0.066101                       0.004955                           0.091237
# 7  0.000771  0.000374  0.006635  0.000825                  0.948995                 0.020831                        0.062507                       0.002180                           0.091657
#
#    eigen_decomposition_wall_sec_std  embedding_normalize_wall_sec_mean  embedding_normalize_wall_sec_std  kmeans_wall_sec_mean  kmeans_wall_sec_std  spectral_clustering_wall_sec_mean  spectral_clustering_wall_sec_std  \
# 0                          0.000944                           0.000095                          0.000077              0.067095             0.057461                           0.083970                          0.057781
# 1                          0.001006                           0.000286                          0.000290              0.076360             0.019029                           0.091533                          0.019264
# 2                          0.001127                           0.000175                          0.000217              0.125035             0.022589                           0.143761                          0.022581
# 3                          0.005421                           0.000206                          0.000183              0.322244             0.082056                           0.362855                          0.083338
# 4                          0.067719                           0.000133                          0.000044              0.524758             0.070752                           0.600905                          0.101270
# 5                          0.013098                           0.000158                          0.000094              0.569561             0.028628                           0.639092                          0.034136
# 6                          0.021140                           0.000197                          0.000113              0.721043             0.049487                           0.812482                          0.042688
# 7                          0.006855                           0.000180                          0.000090              0.819091             0.074118                           0.910931                          0.077257
#
#    metric_wall_sec_mean  metric_wall_sec_std  algorithm_total_wall_sec_mean  algorithm_total_wall_sec_std  cpu_time_sec_mean  cpu_time_sec_std  wall_clock_sec_mean  wall_clock_sec_std  peak_traced_memory_mb_mean  \
# 0              0.020381             0.001825                       2.685185                      0.072648           5.466005          0.255406             3.337414            0.066808                   44.784900
# 1              0.021578             0.002892                       1.805386                      0.056136           4.303436          0.212085             2.242426            0.069673                   28.643429
# 2              0.019029             0.001751                       1.517444                      0.029963           4.307135          0.209669             1.860912            0.025337                   23.043492
# 3              0.017797             0.002135                       1.609455                      0.072845           5.651940          0.716952             1.903044            0.073219                   20.412751
# 4              0.020741             0.013347                       1.885860                      0.237801           5.966135          1.438519             2.163189            0.260207                   18.952947
# 5              0.019996             0.004316                       1.751364                      0.086107           5.300189          0.674914             2.032232            0.096739                   17.632972
# 6              0.015859             0.000740                       1.857800                      0.058659           8.160007          0.392439             2.098908            0.058628                   17.084989
# 7              0.015723             0.000580                       1.922430                      0.064547           8.898320          0.549191             2.155769            0.069448                   16.752422
#
#    peak_traced_memory_mb_std  rss_delta_mb_mean  rss_delta_mb_std  rs_sample_matrix_wall_sec_mean  rs_sample_matrix_wall_sec_std  rs_eig_wall_sec_mean  rs_eig_wall_sec_std  rs_original_upper_nnz_mean  \
# 0                   0.145281          19.304688         27.163307                        0.011236                       0.000765              0.005445             0.000283                    241312.8
# 1                   0.143316          -1.667188          6.136557                        0.007479                       0.000484              0.007350             0.000796                    154650.2
# 2                   0.094003         -10.014062         45.315775                        0.005880                       0.000301              0.012600             0.001007                    124392.3
# 3                   0.091022           1.779688          5.466237                        0.005989                       0.001633              0.034358             0.004770                    110082.3
# 4                   0.082810         -17.056250         49.568242                        0.005365                       0.001066              0.070570             0.067059                    102017.4
# 5                   0.061721           2.782812          5.299916                        0.005657                       0.002830              0.063652             0.010954                     94541.6
# 6                   0.096640           0.842187          2.952959                        0.004566                       0.000424              0.086591             0.020814                     91107.0
# 7                   0.100245           0.435937          0.671025                        0.004488                       0.000376              0.087144             0.006959                     88961.2
#
#    rs_original_upper_nnz_std  rs_sampled_upper_nnz_mean  rs_sampled_upper_nnz_std  rs_sampled_theta_nnz_mean  rs_sampled_theta_nnz_std  top_eigenvalue_max_mean  top_eigenvalue_max_std  top_eigenvalue_min_mean  \
# 0                 781.370278                   168960.1                524.889925                   334422.1               1064.292404                 1.056204                0.001714                 0.858889
# 1                 754.883332                   108249.3                621.444563                   212995.7               1251.329786                 1.057934                0.003052                 0.759912
# 2                 519.341688                    87066.2                341.899855                   170619.1                698.006757                 1.060187                0.002298                 0.710285
# 3                 495.082496                    76988.7                377.799785                   150479.5                756.151550                 1.059234                0.003119                 0.696994
# 4                 463.454469                    71401.3                309.197905                   139285.4                612.051596                 1.062019                0.002673                 0.703872
# 5                 337.951410                    66090.0                238.154478                   128689.9                498.914923                 1.060636                0.002159                 0.711730
# 6                 503.985229                    63910.1                402.979859                   124327.3                823.209849                 1.062981                0.002104                 0.716157
# 7                 560.396249                    62243.2                382.277619                   120995.4                744.287907                 1.061115                0.003238                 0.717942
#
#    top_eigenvalue_min_std
# 0                0.001365
# 1                0.002346
# 2                0.001774
# 3                0.001528
# 4                0.001146
# 5                0.001604
# 6                0.001637
# 7                0.001082

# %% [markdown]
# ## 저장된 파일
#
# 실험이 끝나면 아래 경로에 raw 결과, summary 결과, 설정 파일, 요약 그림이 저장된다.

# %%
outputs["paths"]
# Out:
# {'raw': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_raw.csv'),
#  'summary': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_summary.csv'),
#  'config': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_config.json'),
#  'plot': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_summary.png')}
