# %% [markdown]
# # 균일 HSBM K 변화 - 랜덤 샘플링
#
# 이 노트북은 균일 HSBM의 `K` 변화 실험을 `랜덤 샘플링` 방식으로 실행한다.
#
# 랜덤 샘플링은 `Theta`의 sparse nonzero entry를 확률 `p=0.7`로 뽑고 `1/p`로 rescale한 sampled operator에 `eigsh`를 적용한다.
#
# 하이퍼그래프 생성식은 기존 비랜덤 실험과 동일하게 `p_in = a_in * rho_n / n ** (m - 1)`, `p_out = b_out * rho_n / n ** (m - 1)`를 사용한다.

# %% [markdown]
# ## 실행 설정
#
# 공통 실행 코드는 `uniform_hsbm_randomized.py`에 두었다. 이 노트북은 해당 실행기를 호출하고, raw CSV, summary CSV, 설정 JSON, 요약 그림을 `results/` 아래에 저장한다.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "src" / "common.py").exists():
        PROJECT_ROOT = candidate
        break

EXPERIMENT_DIR = PROJECT_ROOT / "experiments" / "균일 HSBM 실험"
if str(EXPERIMENT_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENT_DIR))

from uniform_hsbm_randomized import resolve_spec, run_named_experiment

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)
SPEC = resolve_spec(sweep='K', method='random_sampling')
SPEC
# Out:
# SweepSpec(sweep='K', method='random_sampling', experiment_id='EXP-20260428-002', experiment_slug='uniform_hsbm_K_sweep_random_sampling', notebook_name='K변화_random_sampling.ipynb', title_ko='균일 HSBM K 변화 - 랜덤 샘플링', x_col='K', x_values=(2, 3, 4, 5, 6, 8, 10, 12), n=5000, K=None, m=3, a_in=36.0, b_out=4.0, rho_n=4.0, reps=10, seed=20260427, sampling='sparse', max_enumeration=1500000, normalize_embedding_rows=True, eigsh_tol=1e-06, rp_oversampling=10, rp_power_iter=2, random_sampling_p=0.7, kmeans_n_init=20)

# %% [markdown]
# ## 실험 실행
#
# 아래 셀을 실행하면 모든 반복을 수행하고 결과 파일을 저장한다.

# %%
outputs = run_named_experiment(sweep='K', method='random_sampling', show_progress=True)
summary = outputs["summary"]
summary
# Out:
# | [----------------------------------]    1/  80 (  1.2%) | K=2 rep=01/10 method=Random sampling   | elapsed=00:01 eta=02:31
# / [----------------------------------]    2/  80 (  2.5%) | K=2 rep=02/10 method=Random sampling   | elapsed=00:03 eta=02:24
# - [#---------------------------------]    3/  80 (  3.8%) | K=2 rep=03/10 method=Random sampling   | elapsed=00:05 eta=02:20
# \ [#---------------------------------]    4/  80 (  5.0%) | K=2 rep=04/10 method=Random sampling   | elapsed=00:07 eta=02:16
# | [##--------------------------------]    5/  80 (  6.2%) | K=2 rep=05/10 method=Random sampling   | elapsed=00:08 eta=02:14
# / [##--------------------------------]    6/  80 (  7.5%) | K=2 rep=06/10 method=Random sampling   | elapsed=00:10 eta=02:11
# - [##--------------------------------]    7/  80 (  8.8%) | K=2 rep=07/10 method=Random sampling   | elapsed=00:12 eta=02:09
# \ [###-------------------------------]    8/  80 ( 10.0%) | K=2 rep=08/10 method=Random sampling   | elapsed=00:14 eta=02:07
# | [###-------------------------------]    9/  80 ( 11.2%) | K=2 rep=09/10 method=Random sampling   | elapsed=00:15 eta=02:05
# / [####------------------------------]   10/  80 ( 12.5%) | K=2 rep=10/10 method=Random sampling   | elapsed=00:17 eta=02:04
# - [####------------------------------]   11/  80 ( 13.8%) | K=3 rep=01/10 method=Random sampling   | elapsed=00:18 eta=01:59
# \ [#####-----------------------------]   12/  80 ( 15.0%) | K=3 rep=02/10 method=Random sampling   | elapsed=00:20 eta=01:54
# | [#####-----------------------------]   13/  80 ( 16.2%) | K=3 rep=03/10 method=Random sampling   | elapsed=00:21 eta=01:50
# / [#####-----------------------------]   14/  80 ( 17.5%) | K=3 rep=04/10 method=Random sampling   | elapsed=00:22 eta=01:47
# - [######----------------------------]   15/  80 ( 18.8%) | K=3 rep=05/10 method=Random sampling   | elapsed=00:23 eta=01:43
# \ [######----------------------------]   16/  80 ( 20.0%) | K=3 rep=06/10 method=Random sampling   | elapsed=00:25 eta=01:40
# | [#######---------------------------]   17/  80 ( 21.2%) | K=3 rep=07/10 method=Random sampling   | elapsed=00:26 eta=01:37
# / [#######---------------------------]   18/  80 ( 22.5%) | K=3 rep=08/10 method=Random sampling   | elapsed=00:27 eta=01:35
# - [########--------------------------]   19/  80 ( 23.8%) | K=3 rep=09/10 method=Random sampling   | elapsed=00:29 eta=01:33
# \ [########--------------------------]   20/  80 ( 25.0%) | K=3 rep=10/10 method=Random sampling   | elapsed=00:30 eta=01:30
# | [########--------------------------]   21/  80 ( 26.2%) | K=4 rep=01/10 method=Random sampling   | elapsed=00:31 eta=01:28
# / [#########-------------------------]   22/  80 ( 27.5%) | K=4 rep=02/10 method=Random sampling   | elapsed=00:32 eta=01:26
# - [#########-------------------------]   23/  80 ( 28.7%) | K=4 rep=03/10 method=Random sampling   | elapsed=00:33 eta=01:23
# \ [##########------------------------]   24/  80 ( 30.0%) | K=4 rep=04/10 method=Random sampling   | elapsed=00:35 eta=01:21
# | [##########------------------------]   25/  80 ( 31.2%) | K=4 rep=05/10 method=Random sampling   | elapsed=00:36 eta=01:19
# / [###########-----------------------]   26/  80 ( 32.5%) | K=4 rep=06/10 method=Random sampling   | elapsed=00:37 eta=01:17
# - [###########-----------------------]   27/  80 ( 33.8%) | K=4 rep=07/10 method=Random sampling   | elapsed=00:38 eta=01:15
# \ [###########-----------------------]   28/  80 ( 35.0%) | K=4 rep=08/10 method=Random sampling   | elapsed=00:39 eta=01:14
# | [############----------------------]   29/  80 ( 36.2%) | K=4 rep=09/10 method=Random sampling   | elapsed=00:41 eta=01:12
# / [############----------------------]   30/  80 ( 37.5%) | K=4 rep=10/10 method=Random sampling   | elapsed=00:42 eta=01:10
# - [#############---------------------]   31/  80 ( 38.8%) | K=5 rep=01/10 method=Random sampling   | elapsed=00:43 eta=01:08
# \ [#############---------------------]   32/  80 ( 40.0%) | K=5 rep=02/10 method=Random sampling   | elapsed=00:44 eta=01:07
# | [##############--------------------]   33/  80 ( 41.2%) | K=5 rep=03/10 method=Random sampling   | elapsed=00:46 eta=01:05
# / [##############--------------------]   34/  80 ( 42.5%) | K=5 rep=04/10 method=Random sampling   | elapsed=00:47 eta=01:04
# - [##############--------------------]   35/  80 ( 43.8%) | K=5 rep=05/10 method=Random sampling   | elapsed=00:48 eta=01:02
# \ [###############-------------------]   36/  80 ( 45.0%) | K=5 rep=06/10 method=Random sampling   | elapsed=00:49 eta=01:01
# | [###############-------------------]   37/  80 ( 46.2%) | K=5 rep=07/10 method=Random sampling   | elapsed=00:51 eta=00:59
# / [################------------------]   38/  80 ( 47.5%) | K=5 rep=08/10 method=Random sampling   | elapsed=00:52 eta=00:58
# - [################------------------]   39/  80 ( 48.8%) | K=5 rep=09/10 method=Random sampling   | elapsed=00:53 eta=00:56
# \ [#################-----------------]   40/  80 ( 50.0%) | K=5 rep=10/10 method=Random sampling   | elapsed=00:55 eta=00:55
# | [#################-----------------]   41/  80 ( 51.2%) | K=6 rep=01/10 method=Random sampling   | elapsed=00:56 eta=00:53
# / [#################-----------------]   42/  80 ( 52.5%) | K=6 rep=02/10 method=Random sampling   | elapsed=00:57 eta=00:51
# - [##################----------------]   43/  80 ( 53.8%) | K=6 rep=03/10 method=Random sampling   | elapsed=00:58 eta=00:50
# \ [##################----------------]   44/  80 ( 55.0%) | K=6 rep=04/10 method=Random sampling   | elapsed=00:59 eta=00:49
# | [###################---------------]   45/  80 ( 56.2%) | K=6 rep=05/10 method=Random sampling   | elapsed=01:01 eta=00:47
# / [###################---------------]   46/  80 ( 57.5%) | K=6 rep=06/10 method=Random sampling   | elapsed=01:02 eta=00:46
# - [###################---------------]   47/  80 ( 58.8%) | K=6 rep=07/10 method=Random sampling   | elapsed=01:03 eta=00:44
# \ [####################--------------]   48/  80 ( 60.0%) | K=6 rep=08/10 method=Random sampling   | elapsed=01:04 eta=00:43
# | [####################--------------]   49/  80 ( 61.3%) | K=6 rep=09/10 method=Random sampling   | elapsed=01:06 eta=00:41
# / [#####################-------------]   50/  80 ( 62.5%) | K=6 rep=10/10 method=Random sampling   | elapsed=01:07 eta=00:40
# - [#####################-------------]   51/  80 ( 63.7%) | K=8 rep=01/10 method=Random sampling   | elapsed=01:08 eta=00:39
# \ [######################------------]   52/  80 ( 65.0%) | K=8 rep=02/10 method=Random sampling   | elapsed=01:09 eta=00:37
# | [######################------------]   53/  80 ( 66.2%) | K=8 rep=03/10 method=Random sampling   | elapsed=01:11 eta=00:36
# / [######################------------]   54/  80 ( 67.5%) | K=8 rep=04/10 method=Random sampling   | elapsed=01:12 eta=00:34
# - [#######################-----------]   55/  80 ( 68.8%) | K=8 rep=05/10 method=Random sampling   | elapsed=01:13 eta=00:33
# \ [#######################-----------]   56/  80 ( 70.0%) | K=8 rep=06/10 method=Random sampling   | elapsed=01:15 eta=00:32
# | [########################----------]   57/  80 ( 71.2%) | K=8 rep=07/10 method=Random sampling   | elapsed=01:16 eta=00:30
# / [########################----------]   58/  80 ( 72.5%) | K=8 rep=08/10 method=Random sampling   | elapsed=01:17 eta=00:29
# - [#########################---------]   59/  80 ( 73.8%) | K=8 rep=09/10 method=Random sampling   | elapsed=01:19 eta=00:28
# \ [#########################---------]   60/  80 ( 75.0%) | K=8 rep=10/10 method=Random sampling   | elapsed=01:20 eta=00:26
# | [#########################---------]   61/  80 ( 76.2%) | K=10 rep=01/10 method=Random sampling   | elapsed=01:21 eta=00:25
# / [##########################--------]   62/  80 ( 77.5%) | K=10 rep=02/10 method=Random sampling   | elapsed=01:22 eta=00:24
# - [##########################--------]   63/  80 ( 78.8%) | K=10 rep=03/10 method=Random sampling   | elapsed=01:24 eta=00:22
# \ [###########################-------]   64/  80 ( 80.0%) | K=10 rep=04/10 method=Random sampling   | elapsed=01:25 eta=00:21
# | [###########################-------]   65/  80 ( 81.2%) | K=10 rep=05/10 method=Random sampling   | elapsed=01:26 eta=00:20
# / [############################------]   66/  80 ( 82.5%) | K=10 rep=06/10 method=Random sampling   | elapsed=01:28 eta=00:18
# - [############################------]   67/  80 ( 83.8%) | K=10 rep=07/10 method=Random sampling   | elapsed=01:29 eta=00:17
# \ [############################------]   68/  80 ( 85.0%) | K=10 rep=08/10 method=Random sampling   | elapsed=01:30 eta=00:16
# | [#############################-----]   69/  80 ( 86.2%) | K=10 rep=09/10 method=Random sampling   | elapsed=01:32 eta=00:14
# / [#############################-----]   70/  80 ( 87.5%) | K=10 rep=10/10 method=Random sampling   | elapsed=01:33 eta=00:13
# - [##############################----]   71/  80 ( 88.8%) | K=12 rep=01/10 method=Random sampling   | elapsed=01:35 eta=00:12
# \ [##############################----]   72/  80 ( 90.0%) | K=12 rep=02/10 method=Random sampling   | elapsed=01:36 eta=00:10
# | [###############################---]   73/  80 ( 91.2%) | K=12 rep=03/10 method=Random sampling   | elapsed=01:37 eta=00:09
# / [###############################---]   74/  80 ( 92.5%) | K=12 rep=04/10 method=Random sampling   | elapsed=01:39 eta=00:08
# - [###############################---]   75/  80 ( 93.8%) | K=12 rep=05/10 method=Random sampling   | elapsed=01:40 eta=00:06
# \ [################################--]   76/  80 ( 95.0%) | K=12 rep=06/10 method=Random sampling   | elapsed=01:42 eta=00:05
# | [################################--]   77/  80 ( 96.2%) | K=12 rep=07/10 method=Random sampling   | elapsed=01:43 eta=00:04
# / [#################################-]   78/  80 ( 97.5%) | K=12 rep=08/10 method=Random sampling   | elapsed=01:44 eta=00:02
# - [#################################-]   79/  80 ( 98.8%) | K=12 rep=09/10 method=Random sampling   | elapsed=01:46 eta=00:01
# \ [##################################]   80/  80 (100.0%) | K=12 rep=10/10 method=Random sampling   | elapsed=01:47 eta=00:00
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 45924 (\N{HANGUL SYLLABLE DEOM}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 47553 (\N{HANGUL SYLLABLE RING}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 45924 (\N{HANGUL SYLLABLE DEOM}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 47553 (\N{HANGUL SYLLABLE RING}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
#     K           method  reps  num_hyperedges_total_mean  num_hyperedges_total_std  hypergraph_degree_mean_mean  hypergraph_degree_mean_std  hypergraph_degree_max_mean  hypergraph_degree_max_std  \
# 0   2  Random sampling    10                    39967.1                171.798622                     23.98026                    0.103079                        43.6                   1.712698
# 1   3  Random sampling    10                    25078.4                 71.963262                     15.04704                    0.043178                        31.2                   1.549193
# 2   4  Random sampling    10                    20063.4                134.258623                     12.03804                    0.080555                        26.8                   1.398412
# 3   5  Random sampling    10                    17566.3                110.380202                     10.53978                    0.066228                        24.3                   1.418136
# 4   6  Random sampling    10                    16276.3                105.995859                      9.76578                    0.063598                        23.4                   0.966092
# 5   8  Random sampling    10                    14983.1                 91.676303                      8.98986                    0.055006                        21.9                   0.737865
# 6  10  Random sampling    10                    14361.5                109.482875                      8.61690                    0.065690                        21.0                   1.154701
# 7  12  Random sampling    10                    14093.9                102.474333                      8.45634                    0.061485                        21.3                   1.337494
#
#    expected_degree_mean_mean  expected_degree_mean_std  candidate_within_fraction_mean  candidate_within_fraction_std  isolated_fraction_mean  isolated_fraction_std  misclassification_mean  misclassification_std  \
# 0                  23.976006                       0.0                        0.249850                            0.0                 0.00000               0.000000                 0.00048               0.000343
# 1                  15.093519                       0.0                        0.110978                            0.0                 0.00000               0.000000                 0.05364               0.004676
# 2                  11.985606                       0.0                        0.062388                            0.0                 0.00000               0.000000                 0.38180               0.048543
# 3                  10.547526                       0.0                        0.039904                            0.0                 0.00004               0.000084                 0.76080               0.010867
# 4                   9.766585                       0.0                        0.027694                            0.0                 0.00002               0.000063                 0.80654               0.004915
# 5                   8.990406                       0.0                        0.015559                            0.0                 0.00016               0.000207                 0.85092               0.004137
# 6                   8.631366                       0.0                        0.009946                            0.0                 0.00028               0.000169                 0.87766               0.002579
# 7                   8.436452                       0.0                        0.006899                            0.0                 0.00018               0.000199                 0.89348               0.001956
#
#    ARI_mean   ARI_std  NMI_mean   NMI_std  generation_wall_sec_mean  generation_wall_sec_std  zhou_theta_build_wall_sec_mean  zhou_theta_build_wall_sec_std  eigen_decomposition_wall_sec_mean  \
# 0  0.998081  0.001369  0.994415  0.003720                  1.216786                 0.021756                        0.085922                       0.003011                           0.011681
# 1  0.845559  0.012927  0.776431  0.015309                  0.810931                 0.029521                        0.055573                       0.003062                           0.013642
# 2  0.253068  0.047167  0.230822  0.041267                  0.654232                 0.020089                        0.043341                       0.001475                           0.023550
# 3  0.006448  0.002224  0.009094  0.002653                  0.589840                 0.015698                        0.038450                       0.000967                           0.033520
# 4  0.001869  0.000648  0.003982  0.000830                  0.547661                 0.015846                        0.035751                       0.000357                           0.033746
# 5  0.000936  0.000485  0.004008  0.000766                  0.517033                 0.008392                        0.033860                       0.001557                           0.043408
# 6  0.000533  0.000528  0.004595  0.000940                  0.495000                 0.011659                        0.033388                       0.001998                           0.055953
# 7  0.000461  0.000213  0.005985  0.000437                  0.497754                 0.019460                        0.031958                       0.001260                           0.061396
#
#    eigen_decomposition_wall_sec_std  embedding_normalize_wall_sec_mean  embedding_normalize_wall_sec_std  kmeans_wall_sec_mean  kmeans_wall_sec_std  spectral_clustering_wall_sec_mean  spectral_clustering_wall_sec_std  \
# 0                          0.001454                           0.000072                          0.000030              0.072067             0.048062                           0.083824                          0.048635
# 1                          0.006173                           0.000128                          0.000071              0.097220             0.017773                           0.110995                          0.020861
# 2                          0.001801                           0.000083                          0.000024              0.270577             0.061538                           0.294214                          0.062208
# 3                          0.007169                           0.000118                          0.000058              0.427926             0.033617                           0.461568                          0.036394
# 4                          0.004277                           0.000081                          0.000004              0.446850             0.047770                           0.480681                          0.047098
# 5                          0.005375                           0.000121                          0.000049              0.522756             0.028606                           0.566289                          0.028616
# 6                          0.008579                           0.000197                          0.000131              0.593503             0.048576                           0.649657                          0.053221
# 7                          0.007192                           0.000114                          0.000004              0.624410             0.066996                           0.685924                          0.068684
#
#    metric_wall_sec_mean  metric_wall_sec_std  algorithm_total_wall_sec_mean  algorithm_total_wall_sec_std  cpu_time_sec_mean  cpu_time_sec_std  wall_clock_sec_mean  wall_clock_sec_std  peak_traced_memory_mb_mean  \
# 0              0.020414             0.002478                       1.386527                      0.047109           3.882379          0.197543             1.742666            0.058582                   22.914607
# 1              0.020427             0.004173                       0.977494                      0.035627           3.459908          0.171828             1.218276            0.040673                   14.738701
# 2              0.018811             0.003681                       0.991783                      0.063040           4.564086          0.458599             1.165773            0.054657                   11.996069
# 3              0.015789             0.001420                       1.089854                      0.036663           5.484027          0.276110             1.240071            0.035501                   10.656662
# 4              0.015473             0.000875                       1.064089                      0.053856           5.565613          0.374409             1.201836            0.056823                    9.982259
# 5              0.016072             0.001749                       1.117178                      0.026771           6.038551          0.191185             1.248010            0.025561                    9.342223
# 6              0.016534             0.002345                       1.178041                      0.056715           6.429477          0.355289             1.308622            0.059412                    9.072067
# 7              0.015261             0.000393                       1.215632                      0.081846           6.647747          0.290118             1.339822            0.080746                    9.000827
#
#    peak_traced_memory_mb_std  rss_delta_mb_mean  rss_delta_mb_std  rs_sample_matrix_wall_sec_mean  rs_sample_matrix_wall_sec_std  rs_eig_wall_sec_mean  rs_eig_wall_sec_std  rs_original_upper_nnz_mean  \
# 0                   0.098374           8.871875         15.136458                        0.005923                       0.000470              0.005705             0.001159                    124062.3
# 1                   0.044948           0.317188          0.597759                        0.004123                       0.000384              0.009479             0.006148                     79908.5
# 2                   0.074825           0.042188          0.059407                        0.003218                       0.000093              0.020311             0.001756                     64991.5
# 3                   0.061515           0.106250          0.314214                        0.002934                       0.000139              0.030557             0.007203                     57561.0
# 4                   0.056900           0.009375          0.024650                        0.002779                       0.000143              0.030949             0.004275                     53724.8
# 5                   0.049027           0.065625          0.108953                        0.002740                       0.000230              0.040656             0.005352                     49861.3
# 6                   0.063192           0.129688          0.158328                        0.002829                       0.000512              0.053090             0.008320                     48007.7
# 7                   0.055554           0.125000          0.183700                        0.002630                       0.000152              0.058739             0.007229                     47206.1
#
#    rs_original_upper_nnz_std  rs_sampled_upper_nnz_mean  rs_sampled_upper_nnz_std  rs_sampled_theta_nnz_mean  rs_sampled_theta_nnz_std  top_eigenvalue_max_mean  top_eigenvalue_max_std  top_eigenvalue_min_mean  \
# 0                 517.924716                    86893.0                399.950275                   170286.4                797.841282                 1.059920                0.001558                 0.871676
# 1                 215.089258                    56022.2                234.045485                   108544.4                453.697697                 1.065083                0.002806                 0.795049
# 2                 391.435889                    45452.8                298.875225                    87413.4                586.336688                 1.065884                0.001541                 0.776999
# 3                 328.447527                    40303.6                275.481477                    77104.1                532.228533                 1.068832                0.002548                 0.794414
# 4                 318.810916                    37644.8                205.237423                    71793.1                392.078068                 1.071077                0.002652                 0.807760
# 5                 270.648624                    34954.1                182.258333                    66401.9                359.335637                 1.073598                0.003145                 0.821189
# 6                 324.467786                    33628.3                285.683994                    63741.7                571.727995                 1.074498                0.002854                 0.827494
# 7                 310.702949                    33085.3                201.761713                    62662.6                386.924971                 1.075021                0.002261                 0.829645
#
#    top_eigenvalue_min_std
# 0                0.002137
# 1                0.005335
# 2                0.001635
# 3                0.001725
# 4                0.002119
# 5                0.002729
# 6                0.002677
# 7                0.001089

# %% [markdown]
# ## 저장된 파일
#
# 실험이 끝나면 아래 경로에 raw 결과, summary 결과, 설정 파일, 요약 그림이 저장된다.

# %%
outputs["paths"]
# Out:
# {'raw': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_raw.csv'),
#  'summary': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_summary.csv'),
#  'config': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_config.json'),
#  'plot': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling/EXP-20260428-002_uniform_hsbm_K_sweep_random_sampling_summary.png')}
