# %% [markdown]
# # 균일 HSBM n 변화 - 랜덤 샘플링
#
# 이 노트북은 균일 HSBM의 `n` 변화 실험을 `랜덤 샘플링` 방식으로 실행한다.
#
# 랜덤 샘플링은 `Theta`의 sparse nonzero entry를 확률 `p=0.7`로 뽑고 `1/p`로 rescale한 sampled operator에 `eigsh`를 적용한다.
#
# 하이퍼그래프 생성식은 기존 비랜덤 실험과 동일하게 `p_in = a_in * rho_n / n ** (m - 1)`, `p_out = b_out * rho_n / n ** (m - 1)`를 사용한다.

# %% [markdown]
# ## 실행 설정
#
# 공통 실행 코드는 `uniform_hsbm_randomized.py`에 두었다. 이 노트북은 해당 실행기를 호출하고, raw CSV, summary CSV, 설정 JSON, 요약 그림을 `results/` 아래에 저장한다.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
for candidate in [PROJECT_ROOT, *PROJECT_ROOT.parents]:
    if (candidate / "src" / "common.py").exists():
        PROJECT_ROOT = candidate
        break

EXPERIMENT_DIR = PROJECT_ROOT / "experiments" / "균일 HSBM 실험"
if str(EXPERIMENT_DIR) not in sys.path:
    sys.path.insert(0, str(EXPERIMENT_DIR))

from uniform_hsbm_randomized import resolve_spec, run_named_experiment

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)
SPEC = resolve_spec(sweep='n', method='random_sampling')
SPEC
# Out:
# SweepSpec(sweep='n', method='random_sampling', experiment_id='EXP-20260428-004', experiment_slug='uniform_hsbm_n_scaling_random_sampling', notebook_name='n변화_random_sampling.ipynb', title_ko='균일 HSBM n 변화 - 랜덤 샘플링', x_col='n', x_values=(1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000), n=None, K=3, m=3, a_in=36.0, b_out=4.0, rho_n=4.0, reps=10, seed=20260426, sampling='sparse', max_enumeration=1500000, normalize_embedding_rows=True, eigsh_tol=1e-06, rp_oversampling=10, rp_power_iter=2, random_sampling_p=0.7, kmeans_n_init=20)

# %% [markdown]
# ## 실험 실행
#
# 아래 셀을 실행하면 모든 반복을 수행하고 결과 파일을 저장한다.

# %%
outputs = run_named_experiment(sweep='n', method='random_sampling', show_progress=True)
summary = outputs["summary"]
summary
# Out:
# | [----------------------------------]    1/ 100 (  1.0%) | n=1000 rep=01/10 method=Random sampling   | elapsed=00:00 eta=00:49
# / [----------------------------------]    2/ 100 (  2.0%) | n=1000 rep=02/10 method=Random sampling   | elapsed=00:00 eta=00:41
# - [#---------------------------------]    3/ 100 (  3.0%) | n=1000 rep=03/10 method=Random sampling   | elapsed=00:01 eta=00:38
# \ [#---------------------------------]    4/ 100 (  4.0%) | n=1000 rep=04/10 method=Random sampling   | elapsed=00:01 eta=00:37
# | [#---------------------------------]    5/ 100 (  5.0%) | n=1000 rep=05/10 method=Random sampling   | elapsed=00:01 eta=00:36
# / [##--------------------------------]    6/ 100 (  6.0%) | n=1000 rep=06/10 method=Random sampling   | elapsed=00:02 eta=00:35
# - [##--------------------------------]    7/ 100 (  7.0%) | n=1000 rep=07/10 method=Random sampling   | elapsed=00:02 eta=00:34
# \ [##--------------------------------]    8/ 100 (  8.0%) | n=1000 rep=08/10 method=Random sampling   | elapsed=00:02 eta=00:33
# | [###-------------------------------]    9/ 100 (  9.0%) | n=1000 rep=09/10 method=Random sampling   | elapsed=00:03 eta=00:33
# / [###-------------------------------]   10/ 100 ( 10.0%) | n=1000 rep=10/10 method=Random sampling   | elapsed=00:03 eta=00:32
# - [###-------------------------------]   11/ 100 ( 11.0%) | n=2000 rep=01/10 method=Random sampling   | elapsed=00:04 eta=00:34
# \ [####------------------------------]   12/ 100 ( 12.0%) | n=2000 rep=02/10 method=Random sampling   | elapsed=00:04 eta=00:35
# | [####------------------------------]   13/ 100 ( 13.0%) | n=2000 rep=03/10 method=Random sampling   | elapsed=00:05 eta=00:36
# / [####------------------------------]   14/ 100 ( 14.0%) | n=2000 rep=04/10 method=Random sampling   | elapsed=00:06 eta=00:36
# - [#####-----------------------------]   15/ 100 ( 15.0%) | n=2000 rep=05/10 method=Random sampling   | elapsed=00:06 eta=00:37
# \ [#####-----------------------------]   16/ 100 ( 16.0%) | n=2000 rep=06/10 method=Random sampling   | elapsed=00:07 eta=00:37
# | [#####-----------------------------]   17/ 100 ( 17.0%) | n=2000 rep=07/10 method=Random sampling   | elapsed=00:07 eta=00:37
# / [######----------------------------]   18/ 100 ( 18.0%) | n=2000 rep=08/10 method=Random sampling   | elapsed=00:08 eta=00:37
# - [######----------------------------]   19/ 100 ( 19.0%) | n=2000 rep=09/10 method=Random sampling   | elapsed=00:08 eta=00:37
# \ [######----------------------------]   20/ 100 ( 20.0%) | n=2000 rep=10/10 method=Random sampling   | elapsed=00:09 eta=00:38
# | [#######---------------------------]   21/ 100 ( 21.0%) | n=3000 rep=01/10 method=Random sampling   | elapsed=00:10 eta=00:38
# / [#######---------------------------]   22/ 100 ( 22.0%) | n=3000 rep=02/10 method=Random sampling   | elapsed=00:11 eta=00:39
# - [#######---------------------------]   23/ 100 ( 23.0%) | n=3000 rep=03/10 method=Random sampling   | elapsed=00:11 eta=00:40
# \ [########--------------------------]   24/ 100 ( 24.0%) | n=3000 rep=04/10 method=Random sampling   | elapsed=00:12 eta=00:40
# | [########--------------------------]   25/ 100 ( 25.0%) | n=3000 rep=05/10 method=Random sampling   | elapsed=00:13 eta=00:40
# / [########--------------------------]   26/ 100 ( 26.0%) | n=3000 rep=06/10 method=Random sampling   | elapsed=00:14 eta=00:41
# - [#########-------------------------]   27/ 100 ( 27.0%) | n=3000 rep=07/10 method=Random sampling   | elapsed=00:15 eta=00:41
# \ [#########-------------------------]   28/ 100 ( 28.0%) | n=3000 rep=08/10 method=Random sampling   | elapsed=00:16 eta=00:41
# | [#########-------------------------]   29/ 100 ( 29.0%) | n=3000 rep=09/10 method=Random sampling   | elapsed=00:16 eta=00:41
# / [##########------------------------]   30/ 100 ( 30.0%) | n=3000 rep=10/10 method=Random sampling   | elapsed=00:17 eta=00:41
# - [##########------------------------]   31/ 100 ( 31.0%) | n=4000 rep=01/10 method=Random sampling   | elapsed=00:18 eta=00:41
# \ [##########------------------------]   32/ 100 ( 32.0%) | n=4000 rep=02/10 method=Random sampling   | elapsed=00:19 eta=00:41
# | [###########-----------------------]   33/ 100 ( 33.0%) | n=4000 rep=03/10 method=Random sampling   | elapsed=00:20 eta=00:42
# / [###########-----------------------]   34/ 100 ( 34.0%) | n=4000 rep=04/10 method=Random sampling   | elapsed=00:21 eta=00:42
# - [###########-----------------------]   35/ 100 ( 35.0%) | n=4000 rep=05/10 method=Random sampling   | elapsed=00:22 eta=00:42
# \ [############----------------------]   36/ 100 ( 36.0%) | n=4000 rep=06/10 method=Random sampling   | elapsed=00:23 eta=00:42
# | [############----------------------]   37/ 100 ( 37.0%) | n=4000 rep=07/10 method=Random sampling   | elapsed=00:24 eta=00:42
# / [############----------------------]   38/ 100 ( 38.0%) | n=4000 rep=08/10 method=Random sampling   | elapsed=00:25 eta=00:42
# - [#############---------------------]   39/ 100 ( 39.0%) | n=4000 rep=09/10 method=Random sampling   | elapsed=00:26 eta=00:42
# \ [#############---------------------]   40/ 100 ( 40.0%) | n=4000 rep=10/10 method=Random sampling   | elapsed=00:27 eta=00:41
# | [#############---------------------]   41/ 100 ( 41.0%) | n=5000 rep=01/10 method=Random sampling   | elapsed=00:29 eta=00:42
# / [##############--------------------]   42/ 100 ( 42.0%) | n=5000 rep=02/10 method=Random sampling   | elapsed=00:30 eta=00:41
# - [##############--------------------]   43/ 100 ( 43.0%) | n=5000 rep=03/10 method=Random sampling   | elapsed=00:31 eta=00:41
# \ [##############--------------------]   44/ 100 ( 44.0%) | n=5000 rep=04/10 method=Random sampling   | elapsed=00:32 eta=00:41
# | [###############-------------------]   45/ 100 ( 45.0%) | n=5000 rep=05/10 method=Random sampling   | elapsed=00:34 eta=00:41
# / [###############-------------------]   46/ 100 ( 46.0%) | n=5000 rep=06/10 method=Random sampling   | elapsed=00:35 eta=00:41
# - [###############-------------------]   47/ 100 ( 47.0%) | n=5000 rep=07/10 method=Random sampling   | elapsed=00:36 eta=00:41
# \ [################------------------]   48/ 100 ( 48.0%) | n=5000 rep=08/10 method=Random sampling   | elapsed=00:37 eta=00:40
# | [################------------------]   49/ 100 ( 49.0%) | n=5000 rep=09/10 method=Random sampling   | elapsed=00:39 eta=00:40
# / [#################-----------------]   50/ 100 ( 50.0%) | n=5000 rep=10/10 method=Random sampling   | elapsed=00:40 eta=00:40
# - [#################-----------------]   51/ 100 ( 51.0%) | n=6000 rep=01/10 method=Random sampling   | elapsed=00:41 eta=00:40
# \ [#################-----------------]   52/ 100 ( 52.0%) | n=6000 rep=02/10 method=Random sampling   | elapsed=00:43 eta=00:39
# | [##################----------------]   53/ 100 ( 53.0%) | n=6000 rep=03/10 method=Random sampling   | elapsed=00:44 eta=00:39
# / [##################----------------]   54/ 100 ( 54.0%) | n=6000 rep=04/10 method=Random sampling   | elapsed=00:46 eta=00:39
# - [##################----------------]   55/ 100 ( 55.0%) | n=6000 rep=05/10 method=Random sampling   | elapsed=00:47 eta=00:38
# \ [###################---------------]   56/ 100 ( 56.0%) | n=6000 rep=06/10 method=Random sampling   | elapsed=00:49 eta=00:38
# | [###################---------------]   57/ 100 ( 57.0%) | n=6000 rep=07/10 method=Random sampling   | elapsed=00:50 eta=00:38
# / [###################---------------]   58/ 100 ( 58.0%) | n=6000 rep=08/10 method=Random sampling   | elapsed=00:52 eta=00:37
# - [####################--------------]   59/ 100 ( 59.0%) | n=6000 rep=09/10 method=Random sampling   | elapsed=00:53 eta=00:37
# \ [####################--------------]   60/ 100 ( 60.0%) | n=6000 rep=10/10 method=Random sampling   | elapsed=00:54 eta=00:36
# | [####################--------------]   61/ 100 ( 61.0%) | n=7000 rep=01/10 method=Random sampling   | elapsed=00:56 eta=00:36
# / [#####################-------------]   62/ 100 ( 62.0%) | n=7000 rep=02/10 method=Random sampling   | elapsed=00:58 eta=00:35
# - [#####################-------------]   63/ 100 ( 63.0%) | n=7000 rep=03/10 method=Random sampling   | elapsed=01:00 eta=00:35
# \ [#####################-------------]   64/ 100 ( 64.0%) | n=7000 rep=04/10 method=Random sampling   | elapsed=01:01 eta=00:34
# | [######################------------]   65/ 100 ( 65.0%) | n=7000 rep=05/10 method=Random sampling   | elapsed=01:03 eta=00:34
# / [######################------------]   66/ 100 ( 66.0%) | n=7000 rep=06/10 method=Random sampling   | elapsed=01:04 eta=00:33
# - [######################------------]   67/ 100 ( 67.0%) | n=7000 rep=07/10 method=Random sampling   | elapsed=01:06 eta=00:32
# \ [#######################-----------]   68/ 100 ( 68.0%) | n=7000 rep=08/10 method=Random sampling   | elapsed=01:08 eta=00:32
# | [#######################-----------]   69/ 100 ( 69.0%) | n=7000 rep=09/10 method=Random sampling   | elapsed=01:09 eta=00:31
# / [#######################-----------]   70/ 100 ( 70.0%) | n=7000 rep=10/10 method=Random sampling   | elapsed=01:11 eta=00:30
# - [########################----------]   71/ 100 ( 71.0%) | n=8000 rep=01/10 method=Random sampling   | elapsed=01:13 eta=00:30
# \ [########################----------]   72/ 100 ( 72.0%) | n=8000 rep=02/10 method=Random sampling   | elapsed=01:15 eta=00:29
# | [########################----------]   73/ 100 ( 73.0%) | n=8000 rep=03/10 method=Random sampling   | elapsed=01:17 eta=00:28
# / [#########################---------]   74/ 100 ( 74.0%) | n=8000 rep=04/10 method=Random sampling   | elapsed=01:19 eta=00:27
# - [#########################---------]   75/ 100 ( 75.0%) | n=8000 rep=05/10 method=Random sampling   | elapsed=01:21 eta=00:27
# \ [#########################---------]   76/ 100 ( 76.0%) | n=8000 rep=06/10 method=Random sampling   | elapsed=01:22 eta=00:26
# | [##########################--------]   77/ 100 ( 77.0%) | n=8000 rep=07/10 method=Random sampling   | elapsed=01:24 eta=00:25
# / [##########################--------]   78/ 100 ( 78.0%) | n=8000 rep=08/10 method=Random sampling   | elapsed=01:26 eta=00:24
# - [##########################--------]   79/ 100 ( 79.0%) | n=8000 rep=09/10 method=Random sampling   | elapsed=01:28 eta=00:23
# \ [###########################-------]   80/ 100 ( 80.0%) | n=8000 rep=10/10 method=Random sampling   | elapsed=01:30 eta=00:22
# | [###########################-------]   81/ 100 ( 81.0%) | n=9000 rep=01/10 method=Random sampling   | elapsed=01:32 eta=00:21
# / [###########################-------]   82/ 100 ( 82.0%) | n=9000 rep=02/10 method=Random sampling   | elapsed=01:35 eta=00:20
# - [############################------]   83/ 100 ( 83.0%) | n=9000 rep=03/10 method=Random sampling   | elapsed=01:37 eta=00:19
# \ [############################------]   84/ 100 ( 84.0%) | n=9000 rep=04/10 method=Random sampling   | elapsed=01:39 eta=00:18
# | [############################------]   85/ 100 ( 85.0%) | n=9000 rep=05/10 method=Random sampling   | elapsed=01:41 eta=00:17
# / [#############################-----]   86/ 100 ( 86.0%) | n=9000 rep=06/10 method=Random sampling   | elapsed=01:43 eta=00:16
# - [#############################-----]   87/ 100 ( 87.0%) | n=9000 rep=07/10 method=Random sampling   | elapsed=01:46 eta=00:15
# \ [#############################-----]   88/ 100 ( 88.0%) | n=9000 rep=08/10 method=Random sampling   | elapsed=01:48 eta=00:14
# | [##############################----]   89/ 100 ( 89.0%) | n=9000 rep=09/10 method=Random sampling   | elapsed=01:50 eta=00:13
# / [##############################----]   90/ 100 ( 90.0%) | n=9000 rep=10/10 method=Random sampling   | elapsed=01:52 eta=00:12
# - [##############################----]   91/ 100 ( 91.0%) | n=10000 rep=01/10 method=Random sampling   | elapsed=01:54 eta=00:11
# \ [###############################---]   92/ 100 ( 92.0%) | n=10000 rep=02/10 method=Random sampling   | elapsed=01:57 eta=00:10
# | [###############################---]   93/ 100 ( 93.0%) | n=10000 rep=03/10 method=Random sampling   | elapsed=01:59 eta=00:08
# / [###############################---]   94/ 100 ( 94.0%) | n=10000 rep=04/10 method=Random sampling   | elapsed=02:01 eta=00:07
# - [################################--]   95/ 100 ( 95.0%) | n=10000 rep=05/10 method=Random sampling   | elapsed=02:04 eta=00:06
# \ [################################--]   96/ 100 ( 96.0%) | n=10000 rep=06/10 method=Random sampling   | elapsed=02:06 eta=00:05
# | [################################--]   97/ 100 ( 97.0%) | n=10000 rep=07/10 method=Random sampling   | elapsed=02:08 eta=00:03
# / [#################################-]   98/ 100 ( 98.0%) | n=10000 rep=08/10 method=Random sampling   | elapsed=02:11 eta=00:02
# - [#################################-]   99/ 100 ( 99.0%) | n=10000 rep=09/10 method=Random sampling   | elapsed=02:13 eta=00:01
# \ [##################################]  100/ 100 (100.0%) | n=10000 rep=10/10 method=Random sampling   | elapsed=02:15 eta=00:00
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 45924 (\N{HANGUL SYLLABLE DEOM}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 47553 (\N{HANGUL SYLLABLE RING}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:602: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) Arial.
#   fig.tight_layout()
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 45924 (\N{HANGUL SYLLABLE DEOM}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 47553 (\N{HANGUL SYLLABLE RING}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
# /Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/uniform_hsbm_randomized.py:603: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) Arial.
#   fig.savefig(out_png, dpi=180, bbox_inches="tight")
#        n           method  reps  num_hyperedges_total_mean  num_hyperedges_total_std  hypergraph_degree_mean_mean  hypergraph_degree_mean_std  hypergraph_degree_max_mean  hypergraph_degree_max_std  \
# 0   1000  Random sampling    10                     5012.9                 71.630921                    15.038700                    0.214893                        28.8                   2.573368
# 1   2000  Random sampling    10                    10065.6                 79.514080                    15.098400                    0.119271                        29.8                   1.398412
# 2   3000  Random sampling    10                    15109.4                150.356022                    15.109400                    0.150356                        30.4                   1.837873
# 3   4000  Random sampling    10                    20159.4                118.558190                    15.119550                    0.088919                        30.5                   1.080123
# 4   5000  Random sampling    10                    25181.6                189.619619                    15.108960                    0.113772                        30.9                   2.330951
# 5   6000  Random sampling    10                    30186.8                271.925153                    15.093400                    0.135963                        31.0                   1.054093
# 6   7000  Random sampling    10                    35245.9                252.998221                    15.105386                    0.108428                        32.7                   1.702939
# 7   8000  Random sampling    10                    40249.8                259.310110                    15.093675                    0.097241                        32.1                   1.449138
# 8   9000  Random sampling    10                    45343.4                252.376791                    15.114467                    0.084126                        31.4                   0.516398
# 9  10000  Random sampling    10                    50329.3                271.344410                    15.098790                    0.081403                        31.4                   1.074968
#
#    expected_degree_mean_mean  expected_degree_mean_std  candidate_within_fraction_mean  candidate_within_fraction_std  isolated_fraction_mean  isolated_fraction_std  misclassification_mean  misclassification_std  \
# 0                  15.023298                       0.0                        0.110445                            0.0                0.000000               0.000000                0.057500               0.007427
# 1                  15.067158                       0.0                        0.110778                            0.0                0.000000               0.000000                0.051850               0.005958
# 2                  15.081794                       0.0                        0.110889                            0.0                0.000000               0.000000                0.055567               0.005026
# 3                  15.089123                       0.0                        0.110944                            0.0                0.000000               0.000000                0.053875               0.003493
# 4                  15.093519                       0.0                        0.110978                            0.0                0.000000               0.000000                0.050880               0.003224
# 5                  15.096448                       0.0                        0.111000                            0.0                0.000017               0.000053                0.052567               0.003400
# 6                  15.098543                       0.0                        0.111016                            0.0                0.000000               0.000000                0.053629               0.003038
# 7                  15.100114                       0.0                        0.111028                            0.0                0.000000               0.000000                0.053638               0.004106
# 8                  15.101335                       0.0                        0.111037                            0.0                0.000000               0.000000                0.053233               0.002381
# 9                  15.102313                       0.0                        0.111044                            0.0                0.000000               0.000000                0.053030               0.003495
#
#    ARI_mean   ARI_std  NMI_mean   NMI_std  generation_wall_sec_mean  generation_wall_sec_std  zhou_theta_build_wall_sec_mean  zhou_theta_build_wall_sec_std  eigen_decomposition_wall_sec_mean  \
# 0  0.834863  0.020389  0.766682  0.024104                  0.184775                 0.013943                        0.012498                       0.000275                           0.003512
# 1  0.850558  0.016522  0.783701  0.019781                  0.345043                 0.008112                        0.022454                       0.000261                           0.005296
# 2  0.840201  0.013808  0.770639  0.015875                  0.492516                 0.017504                        0.033183                       0.000479                           0.007329
# 3  0.844871  0.009634  0.776006  0.011175                  0.638657                 0.017303                        0.043397                       0.001705                           0.009181
# 4  0.853162  0.008937  0.785769  0.010725                  0.808022                 0.020430                        0.054292                       0.001858                           0.011577
# 5  0.848504  0.009396  0.780000  0.010974                  0.963648                 0.021128                        0.066708                       0.001988                           0.014275
# 6  0.845585  0.008397  0.776373  0.010005                  1.121144                 0.015585                        0.075145                       0.001806                           0.015254
# 7  0.845573  0.011303  0.776303  0.013318                  1.294222                 0.026452                        0.089347                       0.003110                           0.017980
# 8  0.846668  0.006568  0.777456  0.007748                  1.462840                 0.045393                        0.101374                       0.003836                           0.020353
# 9  0.847241  0.009651  0.778155  0.011418                  1.602638                 0.032609                        0.110714                       0.003157                           0.022631
#
#    eigen_decomposition_wall_sec_std  embedding_normalize_wall_sec_mean  embedding_normalize_wall_sec_std  kmeans_wall_sec_mean  kmeans_wall_sec_std  spectral_clustering_wall_sec_mean  spectral_clustering_wall_sec_std  \
# 0                          0.000079                           0.000034                          0.000002              0.061917             0.059708                           0.065467                          0.059698
# 1                          0.000124                           0.000055                          0.000016              0.066097             0.011761                           0.071451                          0.011734
# 2                          0.000241                           0.000064                          0.000021              0.086653             0.015238                           0.094050                          0.015302
# 3                          0.000309                           0.000098                          0.000070              0.089173             0.011176                           0.098456                          0.011353
# 4                          0.000603                           0.000106                          0.000069              0.092275             0.020063                           0.103962                          0.019888
# 5                          0.003504                           0.000082                          0.000047              0.093212             0.013086                           0.107573                          0.012337
# 6                          0.000320                           0.000122                          0.000066              0.102732             0.015887                           0.118112                          0.015947
# 7                          0.001519                           0.000129                          0.000056              0.104502             0.020761                           0.122614                          0.020983
# 8                          0.000836                           0.000095                          0.000030              0.106484             0.012166                           0.126936                          0.012534
# 9                          0.000737                           0.000110                          0.000040              0.112796             0.014375                           0.135541                          0.014605
#
#    metric_wall_sec_mean  metric_wall_sec_std  algorithm_total_wall_sec_mean  algorithm_total_wall_sec_std  cpu_time_sec_mean  cpu_time_sec_std  wall_clock_sec_mean  wall_clock_sec_std  peak_traced_memory_mb_mean  \
# 0              0.006837             0.001625                       0.262736                      0.049639           1.925000          0.204876             0.315068            0.055139                    2.882024
# 1              0.009587             0.001615                       0.438945                      0.014729           2.380642          0.243758             0.539280            0.014706                    5.858685
# 2              0.015235             0.002359                       0.619745                      0.025131           2.733724          0.142602             0.776345            0.025702                    8.839679
# 3              0.015906             0.002178                       0.780506                      0.019787           3.225740          0.123554             0.983565            0.025584                   11.822956
# 4              0.020725             0.002476                       0.966272                      0.038334           3.414547          0.259948             1.209666            0.035899                   14.790911
# 5              0.025376             0.002987                       1.137926                      0.021420           3.570646          0.200005             1.427569            0.028087                   17.750284
# 6              0.029257             0.002670                       1.314397                      0.027198           3.924261          0.159148             1.633028            0.024915                   20.736736
# 7              0.032426             0.003319                       1.506179                      0.031461           4.102952          0.173855             1.870116            0.036254                   23.693357
# 8              0.038323             0.004330                       1.691146                      0.055218           4.182929          0.239033             2.130019            0.053295                   26.702702
# 9              0.038727             0.003607                       1.848889                      0.040034           4.636748          0.138517             2.296458            0.047578                   29.653207
#
#    peak_traced_memory_mb_std  rss_delta_mb_mean  rss_delta_mb_std  rs_sample_matrix_wall_sec_mean  rs_sample_matrix_wall_sec_std  rs_eig_wall_sec_mean  rs_eig_wall_sec_std  rs_original_upper_nnz_mean  \
# 0                   0.035958           1.060938          1.633632                        0.001107                       0.000031              0.002397             0.000071                     15732.5
# 1                   0.040384           1.607813          1.100265                        0.001721                       0.000070              0.003563             0.000119                     31870.8
# 2                   0.084745           1.664062          1.468976                        0.002388                       0.000056              0.004920             0.000207                     48004.9
# 3                   0.061989           1.456250          1.249648                        0.003082                       0.000131              0.006076             0.000193                     64158.7
# 4                   0.098353           1.268750          1.473264                        0.003942                       0.000197              0.007616             0.000550                     80213.4
# 5                   0.149143          -3.168750         11.809312                        0.004508                       0.000188              0.009730             0.003487                     96239.4
# 6                   0.145850           0.767188          7.996305                        0.005260                       0.000155              0.009935             0.000352                    112398.4
# 7                   0.145267           0.059375          5.999877                        0.006168                       0.000391              0.011785             0.001364                    128420.5
# 8                   0.150663           1.910937         10.317668                        0.006885                       0.000323              0.013408             0.000585                    144698.7
# 9                   0.147167           1.834375          6.608442                        0.007492                       0.000304              0.015079             0.000490                    160671.3
#
#    rs_original_upper_nnz_std  rs_sampled_upper_nnz_mean  rs_sampled_upper_nnz_std  rs_sampled_theta_nnz_mean  rs_sampled_theta_nnz_std  top_eigenvalue_max_mean  top_eigenvalue_max_std  top_eigenvalue_min_mean  \
# 0                 206.722170                    11006.3                142.506179                    21309.8                286.145185                 1.065164                0.004792                 0.791690
# 1                 230.739295                    22261.3                133.464144                    43123.0                280.485294                 1.062515                0.005320                 0.791604
# 2                 439.739683                    33565.4                360.998369                    65039.4                721.889681                 1.061657                0.003700                 0.792043
# 3                 347.707109                    44872.4                205.114710                    86955.8                404.662219                 1.062879                0.002522                 0.793151
# 4                 565.250819                    56161.2                314.812043                   108811.9                650.637542                 1.064530                0.003310                 0.798024
# 5                 812.409612                    67390.6                543.113698                   130584.9               1088.598227                 1.063055                0.003165                 0.795042
# 6                 770.620991                    78726.9                614.072643                   152526.1               1198.576327                 1.065427                0.003440                 0.795773
# 7                 778.589929                    89917.2                566.990848                   174224.1               1118.196807                 1.064379                0.001728                 0.795610
# 8                 760.975405                   101318.6                681.200607                   196365.5               1372.358169                 1.063008                0.001414                 0.794996
# 9                 810.015096                   112550.8                524.972126                   218083.1               1080.321192                 1.064662                0.001879                 0.796553
#
#    top_eigenvalue_min_std
# 0                0.007343
# 1                0.004636
# 2                0.004021
# 3                0.003842
# 4                0.002397
# 5                0.004683
# 6                0.002378
# 7                0.003666
# 8                0.001565
# 9                0.001418

# %% [markdown]
# ## 저장된 파일
#
# 실험이 끝나면 아래 경로에 raw 결과, summary 결과, 설정 파일, 요약 그림이 저장된다.

# %%
outputs["paths"]
# Out:
# {'raw': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling_raw.csv'),
#  'summary': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling_summary.csv'),
#  'config': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling_config.json'),
#  'plot': PosixPath('/Users/eomjeonghyeon/Documents/github_project/python-rand-nla-research/experiments/균일 HSBM 실험/results/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling/EXP-20260428-004_uniform_hsbm_n_scaling_random_sampling_summary.png')}
