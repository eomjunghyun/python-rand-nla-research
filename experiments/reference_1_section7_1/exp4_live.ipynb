# %% [markdown]
# # Section 7.1 Experiment 4
#
# - `n` variation with `alpha_n = 2 / sqrt(n)`
# - saves raw/summary CSV outputs and the original metric/runtime figures
# - also renders the 19 timing-breakdown plots and the runtime-composition figure from the same notebook

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "reference_1_section7_1":
    PROJECT_ROOT = PROJECT_ROOT.parents[1]
elif PROJECT_ROOT.name == "experiments":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.common import default_exp4_config, default_output_dir, run_and_save_experiment4
from src.common import compute_global_metric_limits, render_all_section7_visualizations

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)

# %%
cfg = default_exp4_config()
show_progress = True
plot_basics = True
detailed_timing = True
outdir = default_output_dir("exp4")

cfg
# Out:
# Exp4Config(n_values=[200, 400, 600, 800, 1000, 1200], K=2, K_prime=2, lam=0.5, q=2, r=10, p=0.7, reps=20, seed=2026)

# %%
outputs = run_and_save_experiment4(
    cfg=cfg,
    outdir=outdir,
    show_progress=show_progress,
    detailed_timing=detailed_timing,
    plot_basics=plot_basics,
)

outputs.to_frame()
# Out:
# \ [##################################]  360/ 360 (100.0%) | n=1200 rep=20/20 method=Non-random        | elapsed=01:44 eta=00:00
#   exp_key                                    label                                             outdir                                            raw_csv                                        summary_csv  \
# 0    exp4  Exp4 (n variation, alpha_n = 2/sqrt(n))  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...
#
#                                       timing_raw_csv                                 timing_summary_csv                                        metrics_png                                        runtime_png  raw_rows  \
# 0  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...       360
#
#    summary_rows
# 0            18

# %%
global_limits = compute_global_metric_limits()
breakdown_result, composition_result = render_all_section7_visualizations(
    exp_key="exp4",
    summary_path=outputs.timing_summary_csv,
    global_limits=global_limits,
)

# %%
breakdown_result.overall_table.round(6)
# Out:
#        n   alpha_n             method  time_sec_mean  time_sec_std
# 0    200  0.141421         Non-random       0.056093      0.020979
# 1    200  0.141421  Random Projection       0.049012      0.017463
# 2    200  0.141421    Random Sampling       0.050064      0.027039
# 3    400  0.100000         Non-random       0.154948      0.060977
# 4    400  0.100000  Random Projection       0.120980      0.060389
# 5    400  0.100000    Random Sampling       0.118455      0.047743
# 6    600  0.081650         Non-random       0.225666      0.068759
# 7    600  0.081650  Random Projection       0.146711      0.064565
# 8    600  0.081650    Random Sampling       0.152428      0.058015
# 9    800  0.070711         Non-random       0.310282      0.083776
# 10   800  0.070711  Random Projection       0.160003      0.082153
# 11   800  0.070711    Random Sampling       0.154061      0.054579
# 12  1000  0.063246         Non-random       0.424638      0.073657
# 13  1000  0.063246  Random Projection       0.201843      0.074039
# 14  1000  0.063246    Random Sampling       0.213726      0.076582
# 15  1200  0.057735         Non-random       0.513103      0.103167
# 16  1200  0.057735  Random Projection       0.173491      0.074135
# 17  1200  0.057735    Random Sampling       0.197782      0.061795
