# %% [markdown]
# # Section 7.1 Experiment 3
#
# - `K` variation experiment
# - saves raw/summary CSV outputs and the original metric/runtime figures
# - also renders the 19 timing-breakdown plots and the runtime-composition figure from the same notebook

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "reference_1_section7_1":
    PROJECT_ROOT = PROJECT_ROOT.parents[1]
elif PROJECT_ROOT.name == "experiments":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.common import default_exp3_config, default_output_dir, run_and_save_experiment3
from src.common import compute_global_metric_limits, render_all_section7_visualizations

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 220)

# %%
cfg = default_exp3_config()
show_progress = True
plot_basics = True
detailed_timing = True
outdir = default_output_dir("exp3")

cfg
# Out:
# Exp3Config(K_values=[2, 3, 4, 5, 6, 7, 8], n=1152, alpha_n=0.2, lam=0.5, q=2, r=10, p=0.7, reps=20, seed=2026)

# %%
outputs = run_and_save_experiment3(
    cfg=cfg,
    outdir=outdir,
    show_progress=show_progress,
    detailed_timing=detailed_timing,
    plot_basics=plot_basics,
)

outputs.to_frame()
# Out:
# \ [##################################]  420/ 420 (100.0%) | K=8 rep=20/20 method=Non-random        | elapsed=03:06 eta=00:00
#   exp_key               label                                             outdir                                            raw_csv                                        summary_csv  \
# 0    exp3  Exp3 (K variation)  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...
#
#                                       timing_raw_csv                                 timing_summary_csv                                        metrics_png                                        runtime_png  raw_rows  \
# 0  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...  /Users/eomjeonghyeon/Documents/github_project/...       420
#
#    summary_rows
# 0            21

# %%
global_limits = compute_global_metric_limits()
breakdown_result, composition_result = render_all_section7_visualizations(
    exp_key="exp3",
    summary_path=outputs.timing_summary_csv,
    global_limits=global_limits,
)

# %%
breakdown_result.overall_table.round(6)
# Out:
#     K             method  time_sec_mean  time_sec_std
# 0   2         Non-random       0.316828      0.047837
# 1   2  Random Projection       0.072352      0.022479
# 2   2    Random Sampling       0.104405      0.033619
# 3   3         Non-random       0.328191      0.068710
# 4   3  Random Projection       0.082536      0.039858
# 5   3    Random Sampling       0.126080      0.040915
# 6   4         Non-random       0.333411      0.039631
# 7   4  Random Projection       0.119472      0.056133
# 8   4    Random Sampling       0.144105      0.038465
# 9   5         Non-random       0.379614      0.076773
# 10  5  Random Projection       0.159075      0.042875
# 11  5    Random Sampling       0.206558      0.070898
# 12  6         Non-random       0.361129      0.041361
# 13  6  Random Projection       0.265403      0.035200
# 14  6    Random Sampling       0.229252      0.054326
# 15  7         Non-random       0.444324      0.083913
# 16  7  Random Projection       0.311240      0.019181
# 17  7    Random Sampling       0.351659      0.060129
# 18  8         Non-random       0.487232      0.046796
# 19  8  Random Projection       0.306661      0.015539
# 20  8    Random Sampling       0.425040      0.036302
